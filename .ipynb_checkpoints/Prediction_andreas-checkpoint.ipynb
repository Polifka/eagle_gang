# %% [markdown]
# # Prediction Task:
# ## _Predict bike rental demand as a function of suitable features available in or derived from the data sets_

# %% [markdown]
# ## Libraries and styles

# %%
# importing all relevant libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from datetime import datetime, timedelta
from haversine import haversine, Unit
from matplotlib.dates import date2num

# %%
# set seaborn styles
sns.set()
sns.set_style("whitegrid")
sns.set_palette("rocket")

# set pandas display styles
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 2000)
pd.set_option('display.max_rows', 500)
# %config IPCompleter.greedy=True

# %% [markdown]
# ## Reading Function

# %%
def read_data(city_name):
    trip_data = pd.read_csv("Project_Data/Combined_Data/"+city_name+".csv", encoding = "ISO-8859-1")
    trip_data["trip_duration"] = pd.to_timedelta(trip_data["trip_duration"])
    trip_data["datetime_start"] = pd.to_datetime(trip_data["datetime_start"])
    trip_data["datetime_end"] = pd.to_datetime(trip_data["datetime_end"])
    trip_data["time"] = pd.to_datetime(trip_data["time"])
    trip_data["day"] = pd.to_datetime(trip_data["day"])
    return trip_data

# %%
dataBr = read_data("Bremen")
dataDu = read_data("Duesseldorf")

# %%
city1 = "Bremen"
city2 = "Duesseldorf"
start_date = "2019-02-01 00:00:00"
end_date = "2019-06-30 23:59:00"
startDate = datetime.fromisoformat(start_date)
endDate = datetime.fromisoformat(end_date)

# %%
# coordinates of city center as [lat, lng]
br_center = [53.078893247451994, 8.8027747491885]
du_center = [51.226815497281706, 6.773786392066722]

# %%
dataBr["distance_from_center_start"] = dataBr.apply(lambda row: haversine((row["orig_lat"], row["orig_lng"]),(br_center[0], br_center[1]),Unit.KILOMETERS), axis=1) 
dataBr["distance_from_center_end"] = dataBr.apply(lambda row: haversine((row["dest_lat"], row["dest_lng"]),(br_center[0], br_center[1]),Unit.KILOMETERS), axis=1) 
dataDu["distance_from_center_start"] = dataDu.apply(lambda row: haversine((row["orig_lat"], row["orig_lng"]),(du_center[0], du_center[1]),Unit.KILOMETERS), axis=1) 
dataDu["distance_from_center_end"] = dataDu.apply(lambda row: haversine((row["dest_lat"], row["dest_lng"]),(du_center[0], du_center[1]),Unit.KILOMETERS), axis=1)

# %% [markdown]
# ***

# %% [markdown]
# ## Data for Prediction Task

# %% [markdown]
# ### Prepare data
# Since we have data sets with single entries (trips) at one specific point of time, it does not make sense to take a value from the single entries as a target (since there is no "rental demand" associated with a single trip). Rather, we have to group the trips by a time unit, e.g. hour or day, and aggregate the number of trips per time unit, so there is a target associated with our data that can be predicted.

# %%
dataBr.head()
# Out:
#    Unnamed: 0        day                time  b_number    city trip_duration   orig_lat  orig_lng   dest_lat  dest_lng  ... fleetsize_monthly  distance  trip_duration_hours  avg_speed  rounded_time_hourly  temp  wind  rain  distance_from_center_start  distance_from_center_end
# 0           0 2019-04-21 2021-02-04 17:34:00     20507  bremen      00:13:00  53.078923  8.884911  53.078711  8.899906  ...               395  1.001900             0.216667   4.624155  2019-04-21 18:00:00  20.4   2.0   0.0                    5.486415                  6.488083
# 1           1 2019-05-23 2021-02-04 15:33:00     20507  bremen      00:07:00  53.078923  8.884911  53.078004  8.876828  ...               373  0.549476             0.116667   4.709793  2019-05-23 16:00:00  20.7   2.4   0.0                    5.486415                  4.947560
# 2           2 2019-06-14 2021-02-04 22:30:00     20507  bremen      00:08:00  53.078923  8.884911  53.074731  8.876003  ...               342  0.755886             0.133333   5.669146  2019-06-14 22:00:00  19.6   4.4   0.0                    5.486415                  4.913475
# 3           3 2019-06-16 2021-02-04 10:00:00     20507  bremen      02:02:00  53.074731  8.876003  53.078923  8.884911  ...               342  0.755886             2.033333   0.371747  2019-06-16 10:00:00  21.6   3.0   0.0                    4.913475                  5.486415
# 4           4 2019-06-16 2021-02-04 12:55:00     20507  bremen      02:23:00  53.078923  8.884911  53.076236  8.891322  ...               342  0.522213             2.383333   0.219110  2019-06-16 13:00:00  21.8   4.4   0.0                    5.486415                  5.922224
#
# [5 rows x 28 columns]

# %% [markdown]
# #### Drop columns that are obviously neither relevant nor useful

# %%
dBr = dataBr.drop(["Unnamed: 0","b_number","day","time","city","fleetsize_weekly","fleetsize_dayly","fleetsize_monthly"], axis=1)
dDu = dataDu.drop(["Unnamed: 0","b_number","day","time","city","fleetsize_weekly","fleetsize_dayly","fleetsize_monthly"], axis=1)

# %%
# group the trips by either hour or day
def process_data_for_city(data, city, start_date, end_date, group):
    '''
    Processes given data and calculates the revenue per hour for a given city in a given time window. Also groups by 
    a given param (hour or day)

    :param data: the dataFrame of a given city
    :param city: a city in string format, e.g. "Bremen" or "Duesseldorf"
    :param start_date: an iso format time string, e.g. "2019-03-28 12:00:00"
    :param end_date: an iso format time string, e.g. "2019-03-31 12:00:00"
    :param group: a string, either "hour" or "day"
    '''

    # sorting of data
    dat = data.sort_values(by=['datetime_start'], axis=0)
 
    def calc_revenue(x):
        '''
        Counts trip duration intervals for each trip, i.e. how much revenue each trip generated,
        by setting the revenue to the number of 30-minute durations fitting into the trip duration,
        and add 1 to the revenue if division of trip duration by 30-minute interval has a remainder
        
        Examples: 
        If a trip was 30 mins long: trip duration / 30 mins --> revenue = 1 
        If a trip was 1 hour 12 mins long: trip duration / 30 mins = 2, remainder = 12 --> revenue = 2+1 = 3
        
        :param x: a trip/row
        '''
        if (x % pd.Timedelta(minutes=30)) > pd.Timedelta(minutes=0):
            return float(math.floor(x / pd.Timedelta(minutes=30) + 1))
        else:
            return float(math.floor(x / pd.Timedelta(minutes=30)))
                              
    # apply calculation to each row
    dat["revenue_per_trip"] = dat["trip_duration"].apply(lambda x: calc_revenue(x))

    # select rows in the given time window
    dat_time_framed = dat.loc[(dat["datetime_start"] > startDate) & (dat["datetime_start"] <= endDate)]
    
    
    # Group data in the given time window by month, day and hours to get to specific hourly level
    # and aggregate on several columns
    times = pd.DatetimeIndex(dat_time_framed.datetime_start)
    grouping = [times.month, times.day, times.hour] if group == "hour" else  [times.month, times.day]
    dat_time_framed["inner"] = dat_time_framed["distance_from_center_start"] <= 1
    groupedBy = dat_time_framed.groupby(grouping).agg(trips_per_time=("datetime_start","count"), revenue_per_time=("revenue_per_trip","sum"), avg_temp=("temp","mean"), avg_wind=("wind","mean"), avg_rain=("rain","mean"), avg_distance=("distance","mean"), innerCity=("inner","sum"), innerCityMean=("inner","mean"),avg_dist_from_center_start=("distance_from_center_start","mean"), avg_dist_from_center_end=("distance_from_center_end","mean"))
   
    # reset index to get the groupedBy values back as columns
    groupedBy.index.rename(["month", "day", "hour"] if group == "hour" else ["month","day"], inplace=True)
    groupedBy.reset_index(inplace=True)
    
    # generate string date column
    groupedBy["date"] = "2019-" + groupedBy["month"].astype(str) + "-" +  groupedBy["day"].astype(str) + " 00:00:00"

    # generate datetime column for checking of weekdays and remove string date column
    groupedBy["datetime"] = [pd.to_datetime(d) for d in groupedBy.date]
    groupedBy.drop(["date"], axis=1, inplace=True)

    # generate weekday column for later use
    groupedBy["weekday"] = [dt.weekday() for dt in groupedBy.datetime]
    groupedBy.drop(["datetime"], axis=1, inplace=True)


    # check, if date is weekday (.weekday() returns 0 for a monday, and 6 for a sunday)
    groupedBy["is_weekday"] = groupedBy["weekday"] <=4
    groupedBy.drop(["weekday"], axis=1, inplace=True)
    
    # function determining the peak time; col1 (weekdays) at rush hour time and col2(weekend) spread over the noon/afternoon
    def isPeaktime(col1, col2):
        if ( ((col1 == True) and (col2 in (5,6,7,8,15,16,17))) or ((col1 == False) and (col2 in (10,11,12,13,14,15,16)))):
            return True
        else: 
            return False
    
    # function determining dark hours; based on col1(hour)
    def isDark(col1):
        if col1 > 19 or col1 < 6:
            return True
        else: 
            return False
        
    # function determining rainy hours
    def isRainy(col1):
        if col1 > 0.3:
            return True
        else: 
            return False
        
    # function determining windy hours
    def isWindy(col1):
        if col1 >= 8:
            return True
        else: 
            return False
        
    groupedBy["is_peaktime"] = groupedBy.apply(lambda row: isPeaktime(row.is_weekday, row.hour), axis=1)
    groupedBy["is_dark"] = groupedBy.apply(lambda row: isDark(row.hour), axis=1)
    groupedBy["is_rainy"] = groupedBy.apply(lambda row: isRainy(row.avg_rain), axis=1)
    groupedBy["is_windy"] = groupedBy.apply(lambda row: isWindy(row.avg_wind), axis=1)
    
    return groupedBy

# %%
TIME_FRAME="hour"

# %%
br = process_data_for_city(dBr, city1, startDate, endDate, TIME_FRAME)
du = process_data_for_city(dDu, city2, startDate, endDate, TIME_FRAME)

# %% [markdown]
# ***
# ## Correlation Analysis

# %% [markdown]
# The goal is to select those features (from the set of all features) that are optimally least correlated with each other and highly correlated with the target. As a guideline we could take a boundary correlation value of 0.3 or -0.3 to detect very low correlation and take at least low to medium correlation into consideration. However, some features with low correlation values still might be valuable for the prediction task, and a low correlation value might not filter those out (e.g. wind strength obviously has an impact on driven distance). As a result, all features with correlation below between 0.05 and -0.05 are considered not correlated with each other and are assumed to be able to be independently used in a feature set. The same values apply to selecting those features correlated with the target. However, correlation with the target should be maximized.
#
# https://journals.sagepub.com/doi/pdf/10.1177/875647939000600106
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3576830/

# %% [markdown]
# #### on unprepared data

# %%
# showing the highest correlation values for a given data set with a given correlation metric
# disregards values equal to 1 at the diagonal
def show_high_corr(data, posMin, negMin, corr_method):
    corr = data.corr(method=corr_method)
    corr_val = np.array(corr)
    rows, cols = corr.shape
    flds = list(corr.columns)
    high_corr = []
    
    for i in range(cols):
        for j in range(i, cols):
            if corr_val[i,j] > posMin or corr_val[i,j] < negMin:
                if(i!=j):
                    high_corr.append([flds[i], flds[j], corr_val[i,j]])
    df = pd.DataFrame(high_corr, columns = ['col1', 'col2', 'correlation'])
    return df

# %%
# BREMEN, PEARSON CORRELATION
all_br_pe = show_high_corr(dBr, 0.05, -0.05, "pearson")
all_br_pe
# Out:
#                           col1                        col2  correlation
# 0                     orig_lat                    orig_lng    -0.070743
# 1                     orig_lat                    dest_lat     0.666620
# 2                     orig_lat                    dest_lng    -0.069857
# 3                     orig_lat                    distance     0.098017
# 4                     orig_lat         trip_duration_hours     0.056897
# 5                     orig_lat    distance_from_center_end    -0.064568
# 6                     orig_lng                    dest_lat    -0.066708
# 7                     orig_lng                    dest_lng     0.642663
# 8                     orig_lng                    distance     0.050057
# 9                     orig_lng  distance_from_center_start     0.519234
# 10                    orig_lng    distance_from_center_end     0.333468
# 11                    dest_lat                    dest_lng    -0.072469
# 12                    dest_lat                    distance     0.101439
# 13                    dest_lat  distance_from_center_start    -0.063871
# 14                    dest_lng                        hour     0.074545
# 15                    dest_lng                    distance     0.067554
# 16                    dest_lng  distance_from_center_start     0.333126
# 17                    dest_lng    distance_from_center_end     0.521682
# 18                     weekday                       month     0.054795
# 19                     weekday         trip_duration_hours     0.069665
# 20                     weekday                   avg_speed    -0.054027
# 21                     weekday                        wind    -0.135769
# 22                     weekday                        rain    -0.051645
# 23                       month                        week     0.976644
# 24                       month                    distance     0.050110
# 25                       month                        temp     0.686158
# 26                       month                        wind    -0.082592
# 27                        hour                        temp     0.145488
# 28                        hour                        wind     0.055071
# 29                        week                    distance     0.051888
# 30                        week                        temp     0.722585
# 31                        week                        wind    -0.110579
# 32                    distance         trip_duration_hours     0.228120
# 33                    distance                   avg_speed     0.531795
# 34                    distance  distance_from_center_start     0.165738
# 35                    distance    distance_from_center_end     0.201817
# 36         trip_duration_hours                   avg_speed    -0.392765
# 37         trip_duration_hours                        temp     0.110114
# 38                   avg_speed                        temp    -0.100231
# 39                   avg_speed  distance_from_center_start     0.052689
# 40                   avg_speed    distance_from_center_end     0.068264
# 41                        temp                        rain    -0.053229
# 42  distance_from_center_start    distance_from_center_end     0.668333

# %%
# BREMEN, SPEARMAN CORRELATION
all_br_sp = show_high_corr(dBr, 0.05, -0.05, "spearman")
all_br_sp
# Out:
#                           col1                        col2  correlation
# 0                     orig_lat                    dest_lat     0.455863
# 1                     orig_lat                    distance     0.060518
# 2                     orig_lat         trip_duration_hours     0.050182
# 3                     orig_lng                    dest_lng     0.516679
# 4                     orig_lng  distance_from_center_start     0.557024
# 5                     orig_lng    distance_from_center_end     0.316041
# 6                     dest_lat                        hour    -0.065336
# 7                     dest_lat                    distance     0.056946
# 8                     dest_lng                        hour     0.088366
# 9                     dest_lng  distance_from_center_start     0.317261
# 10                    dest_lng    distance_from_center_end     0.567216
# 11                     weekday                       month     0.061223
# 12                     weekday         trip_duration_hours     0.098117
# 13                     weekday                   avg_speed    -0.055699
# 14                     weekday                        wind    -0.149264
# 15                     weekday                        rain    -0.059010
# 16                       month                        week     0.972424
# 17                       month         trip_duration_hours     0.075689
# 18                       month                        temp     0.711116
# 19                       month                        wind    -0.065019
# 20                       month  distance_from_center_start     0.062404
# 21                       month    distance_from_center_end     0.062854
# 22                        hour                        temp     0.121323
# 23                        hour    distance_from_center_end     0.104935
# 24                        week         trip_duration_hours     0.076549
# 25                        week                        temp     0.744299
# 26                        week                        wind    -0.075756
# 27                        week  distance_from_center_start     0.061660
# 28                        week    distance_from_center_end     0.062455
# 29                    distance         trip_duration_hours     0.591308
# 30                    distance                   avg_speed     0.621012
# 31                    distance                        wind    -0.055574
# 32                    distance  distance_from_center_start     0.161111
# 33                    distance    distance_from_center_end     0.166821
# 34         trip_duration_hours                   avg_speed    -0.118377
# 35         trip_duration_hours                        temp     0.124670
# 36         trip_duration_hours  distance_from_center_start     0.121893
# 37         trip_duration_hours    distance_from_center_end     0.121846
# 38                   avg_speed                        temp    -0.101261
# 39                   avg_speed  distance_from_center_start     0.072734
# 40                   avg_speed    distance_from_center_end     0.080084
# 41                        temp                        rain    -0.101549
# 42                        temp  distance_from_center_start     0.061783
# 43                        temp    distance_from_center_end     0.070556
# 44                        wind                        rain     0.055194
# 45  distance_from_center_start    distance_from_center_end     0.355180

# %% [markdown]
# ##### Bremen
# - geo coordinates have a strong positive correlation with each other
# - geo coordinates have a strong positive correlation with distance from city center
#
# **-->** remove geo coordinates or take only one out of those features with geo coordinates / distance from center
#
# - month, hour and week are highly positively correlated with temp
#
# **-->** try maybe with one out of [month,day,hour] plus temperature (e.g. since both hour and temp could be a valuable feature), or only temperature, or only time values
#
# - distance is highly correlated with trip duration in hours, average speed
#
# **-->** here, take only one feature, since they all rely on each other
#
#
# **lower correlation values that still might be relevant**
# - distance is negatively correlated with wind
# - trip duration is positively correlated with wind
# - avg speed is negatively correlated with temperature
# - temperature is negatively correlated with rain
# - weekday is positively correlated with trip duration and negatively correlated with average speed

# %%
# DÜSSELDORF, PEARSON CORRELATION
all_du_pe = show_high_corr(dDu, 0.05, -0.05, "pearson")
all_du_pe
# Out:
#                           col1                        col2  correlation
# 0                     orig_lat                    orig_lng    -0.111232
# 1                     orig_lat                    dest_lat     0.720237
# 2                     orig_lat                    dest_lng    -0.098727
# 3                     orig_lat                       month    -0.115170
# 4                     orig_lat                        week    -0.127535
# 5                     orig_lat                    distance     0.218181
# 6                     orig_lat         trip_duration_hours     0.064961
# 7                     orig_lat                   avg_speed     0.072530
# 8                     orig_lat                        temp    -0.107898
# 9                     orig_lat  distance_from_center_start     0.114302
# 10                    orig_lng                    dest_lat    -0.111209
# 11                    orig_lng                    dest_lng     0.614139
# 12                    orig_lng                     weekday    -0.060462
# 13                    orig_lng         trip_duration_hours    -0.069887
# 14                    orig_lng  distance_from_center_start     0.483375
# 15                    orig_lng    distance_from_center_end     0.450291
# 16                    dest_lat                    dest_lng    -0.166755
# 17                    dest_lat                       month    -0.120007
# 18                    dest_lat                        week    -0.130805
# 19                    dest_lat                    distance     0.127817
# 20                    dest_lat         trip_duration_hours     0.063750
# 21                    dest_lat                        temp    -0.115439
# 22                    dest_lng                     weekday    -0.067388
# 23                    dest_lng                    distance    -0.086186
# 24                    dest_lng         trip_duration_hours    -0.087322
# 25                    dest_lng  distance_from_center_start     0.449899
# 26                    dest_lng    distance_from_center_end     0.490173
# 27                     weekday         trip_duration_hours     0.060852
# 28                     weekday                   avg_speed    -0.077548
# 29                     weekday                        wind     0.067778
# 30                     weekday  distance_from_center_start    -0.052741
# 31                       month                        hour     0.077439
# 32                       month                        week     0.965694
# 33                       month                    distance    -0.061418
# 34                       month         trip_duration_hours    -0.096838
# 35                       month                        temp     0.617446
# 36                        hour                        week     0.081608
# 37                        hour         trip_duration_hours    -0.056886
# 38                        hour                        temp     0.192913
# 39                        week                    distance    -0.063059
# 40                        week         trip_duration_hours    -0.098813
# 41                        week                        temp     0.672457
# 42                    distance         trip_duration_hours     0.228750
# 43                    distance                   avg_speed     0.440498
# 44                    distance  distance_from_center_start     0.252681
# 45                    distance    distance_from_center_end     0.137894
# 46         trip_duration_hours                   avg_speed    -0.476062
# 47                   avg_speed                        temp    -0.063685
# 48                   avg_speed  distance_from_center_start     0.107487
# 49                   avg_speed    distance_from_center_end     0.083275
# 50                        temp                        wind     0.130979
# 51                        temp                        rain    -0.060179
# 52  distance_from_center_start    distance_from_center_end     0.720708

# %%
# DÜSSELDORF, SPEARMAN CORRELATION
results_du_sp = show_high_corr(dDu, 0.05, -0.05, "spearman")
results_du_sp
# Out:
#                           col1                        col2  correlation
# 0                     orig_lat                    orig_lng    -0.112720
# 1                     orig_lat                    dest_lat     0.625418
# 2                     orig_lat                    dest_lng    -0.104434
# 3                     orig_lat                       month    -0.178435
# 4                     orig_lat                        week    -0.195161
# 5                     orig_lat                    distance     0.127378
# 6                     orig_lat         trip_duration_hours     0.102637
# 7                     orig_lat                        temp    -0.133824
# 8                     orig_lat    distance_from_center_end    -0.075555
# 9                     orig_lng                    dest_lat    -0.111214
# 10                    orig_lng                    dest_lng     0.462044
# 11                    orig_lng                     weekday    -0.083412
# 12                    orig_lng                       month     0.056257
# 13                    orig_lng                        hour    -0.065908
# 14                    orig_lng                        week     0.060404
# 15                    orig_lng                    distance    -0.092107
# 16                    orig_lng         trip_duration_hours    -0.160667
# 17                    orig_lng                   avg_speed     0.061878
# 18                    orig_lng  distance_from_center_start     0.377244
# 19                    orig_lng    distance_from_center_end     0.230020
# 20                    dest_lat                    dest_lng    -0.111307
# 21                    dest_lat                       month    -0.177710
# 22                    dest_lat                        week    -0.196311
# 23                    dest_lat                    distance     0.123857
# 24                    dest_lat         trip_duration_hours     0.102277
# 25                    dest_lat                        temp    -0.140978
# 26                    dest_lat  distance_from_center_start    -0.089083
# 27                    dest_lng                     weekday    -0.088465
# 28                    dest_lng                       month     0.056219
# 29                    dest_lng                        week     0.060737
# 30                    dest_lng                    distance    -0.101677
# 31                    dest_lng         trip_duration_hours    -0.159672
# 32                    dest_lng                   avg_speed     0.055153
# 33                    dest_lng  distance_from_center_start     0.217839
# 34                    dest_lng    distance_from_center_end     0.366026
# 35                     weekday         trip_duration_hours     0.093206
# 36                     weekday                   avg_speed    -0.086385
# 37                     weekday                        temp     0.057023
# 38                     weekday                        wind     0.061485
# 39                     weekday  distance_from_center_start    -0.076587
# 40                     weekday    distance_from_center_end    -0.058169
# 41                       month                        hour     0.093040
# 42                       month                        week     0.901037
# 43                       month                    distance    -0.091384
# 44                       month         trip_duration_hours    -0.118104
# 45                       month                        temp     0.660971
# 46                       month  distance_from_center_start     0.084022
# 47                       month    distance_from_center_end     0.081675
# 48                        hour                        week     0.089902
# 49                        hour                        temp     0.158676
# 50                        hour                        wind    -0.057282
# 51                        hour  distance_from_center_start    -0.076074
# 52                        week                    distance    -0.085652
# 53                        week         trip_duration_hours    -0.122461
# 54                        week                        temp     0.710122
# 55                        week                        rain    -0.063496
# 56                        week  distance_from_center_start     0.095130
# 57                        week    distance_from_center_end     0.096909
# 58                    distance         trip_duration_hours     0.466940
# 59                    distance                   avg_speed     0.541234
# 60                    distance  distance_from_center_start     0.068387
# 61                    distance    distance_from_center_end     0.068099
# 62         trip_duration_hours                   avg_speed    -0.351040
# 63         trip_duration_hours  distance_from_center_start    -0.063333
# 64         trip_duration_hours    distance_from_center_end    -0.068926
# 65                   avg_speed                        temp    -0.067872
# 66                   avg_speed  distance_from_center_start     0.126226
# 67                   avg_speed    distance_from_center_end     0.134101
# 68                        temp                        wind     0.162969
# 69                        temp                        rain    -0.150866
# 70                        temp  distance_from_center_start     0.057521
# 71  distance_from_center_start    distance_from_center_end     0.414580

# %% [markdown]
# ##### Düsseldorf
# - similar to Bremen

# %% [markdown]
# #### on prepared data

# %%
# BREMEN, PEARSON CORRELATION
prep_br_pe = show_high_corr(br, 0.05, -0.05, "pearson")
prep_br_pe
# Out:
#                           col1                        col2  correlation
# 0                        month              trips_per_time     0.338867
# 1                        month            revenue_per_time     0.329102
# 2                        month                    avg_temp     0.687527
# 3                        month                    avg_wind    -0.113449
# 4                        month                avg_distance     0.151357
# 5                        month                   innerCity     0.221351
# 6                        month               innerCityMean    -0.083954
# 7                        month  avg_dist_from_center_start     0.053164
# 8                        month    avg_dist_from_center_end     0.075282
# 9                        month                    is_windy    -0.177736
# 10                         day              trips_per_time     0.117279
# 11                         day            revenue_per_time     0.126385
# 12                         day                    avg_temp     0.234723
# 13                         day                    avg_wind    -0.193221
# 14                         day                    avg_rain    -0.092508
# 15                         day                avg_distance     0.053692
# 16                         day                   innerCity     0.077098
# 17                         day                    is_rainy    -0.080112
# 18                         day                    is_windy    -0.141370
# 19                        hour              trips_per_time     0.217539
# 20                        hour            revenue_per_time     0.200059
# 21                        hour                    avg_temp     0.147929
# 22                        hour                    avg_wind     0.103206
# 23                        hour                avg_distance    -0.085894
# 24                        hour                   innerCity     0.160302
# 25                        hour  avg_dist_from_center_start    -0.064843
# 26                        hour                 is_peaktime    -0.054614
# 27                        hour                     is_dark    -0.126253
# 28                        hour                    is_windy     0.050297
# 29              trips_per_time            revenue_per_time     0.934448
# 30              trips_per_time                    avg_temp     0.561897
# 31              trips_per_time                    avg_wind     0.115841
# 32              trips_per_time                    avg_rain    -0.079403
# 33              trips_per_time                   innerCity     0.836820
# 34              trips_per_time    avg_dist_from_center_end    -0.072669
# 35              trips_per_time                  is_weekday     0.110065
# 36              trips_per_time                 is_peaktime     0.410457
# 37              trips_per_time                     is_dark    -0.535369
# 38              trips_per_time                    is_rainy    -0.078488
# 39              trips_per_time                    is_windy    -0.063367
# 40            revenue_per_time                    avg_temp     0.581278
# 41            revenue_per_time                    avg_wind     0.113995
# 42            revenue_per_time                    avg_rain    -0.078937
# 43            revenue_per_time                   innerCity     0.762177
# 44            revenue_per_time    avg_dist_from_center_end    -0.052823
# 45            revenue_per_time                  is_weekday     0.052121
# 46            revenue_per_time                 is_peaktime     0.384801
# 47            revenue_per_time                     is_dark    -0.523455
# 48            revenue_per_time                    is_rainy    -0.079664
# 49            revenue_per_time                    is_windy    -0.066886
# 50                    avg_temp                    avg_wind     0.062305
# 51                    avg_temp                avg_distance     0.103273
# 52                    avg_temp                   innerCity     0.406761
# 53                    avg_temp               innerCityMean    -0.070243
# 54                    avg_temp  avg_dist_from_center_start     0.057118
# 55                    avg_temp    avg_dist_from_center_end     0.057437
# 56                    avg_temp                 is_peaktime     0.111514
# 57                    avg_temp                     is_dark    -0.297288
# 58                    avg_temp                    is_windy    -0.071188
# 59                    avg_wind                avg_distance    -0.118091
# 60                    avg_wind                   innerCity     0.140393
# 61                    avg_wind               innerCityMean     0.072425
# 62                    avg_wind                  is_weekday     0.098597
# 63                    avg_wind                 is_peaktime     0.100014
# 64                    avg_wind                     is_dark    -0.304448
# 65                    avg_wind                    is_rainy     0.087076
# 66                    avg_wind                    is_windy     0.628055
# 67                    avg_rain                avg_distance    -0.068653
# 68                    avg_rain                   innerCity    -0.062125
# 69                    avg_rain                    is_rainy     0.752093
# 70                    avg_rain                    is_windy     0.050730
# 71                avg_distance                   innerCity    -0.076769
# 72                avg_distance               innerCityMean    -0.070025
# 73                avg_distance  avg_dist_from_center_start     0.156874
# 74                avg_distance    avg_dist_from_center_end     0.311460
# 75                avg_distance                     is_dark     0.166181
# 76                avg_distance                    is_rainy    -0.076261
# 77                avg_distance                    is_windy    -0.090731
# 78                   innerCity               innerCityMean     0.357577
# 79                   innerCity  avg_dist_from_center_start    -0.174562
# 80                   innerCity    avg_dist_from_center_end    -0.146249
# 81                   innerCity                  is_weekday     0.196951
# 82                   innerCity                 is_peaktime     0.291850
# 83                   innerCity                     is_dark    -0.487641
# 84                   innerCity                    is_rainy    -0.060843
# 85               innerCityMean  avg_dist_from_center_start    -0.490594
# 86               innerCityMean    avg_dist_from_center_end    -0.178075
# 87               innerCityMean                  is_weekday     0.079468
# 88               innerCityMean                 is_peaktime    -0.058603
# 89  avg_dist_from_center_start    avg_dist_from_center_end     0.639870
# 90  avg_dist_from_center_start                 is_peaktime     0.063882
# 91    avg_dist_from_center_end                 is_peaktime    -0.065862
# 92    avg_dist_from_center_end                     is_dark     0.118183
# 93                 is_peaktime                     is_dark    -0.393711
# 94                 is_peaktime                    is_rainy     0.050139
# 95                     is_dark                    is_rainy    -0.071012
# 96                     is_dark                    is_windy    -0.077651
# 97                    is_rainy                    is_windy     0.065686

# %%
# BREMEN, SPEARMAN CORRELATION
prep_br_sp = show_high_corr(br, 0.05, -0.05, "spearman")
prep_br_sp
# Out:
#                            col1                        col2  correlation
# 0                         month              trips_per_time     0.315185
# 1                         month            revenue_per_time     0.319983
# 2                         month                    avg_temp     0.697175
# 3                         month                    avg_wind    -0.077939
# 4                         month                avg_distance     0.174323
# 5                         month                   innerCity     0.212236
# 6                         month               innerCityMean    -0.074162
# 7                         month  avg_dist_from_center_start     0.137824
# 8                         month    avg_dist_from_center_end     0.145631
# 9                         month                    is_windy    -0.178611
# 10                          day              trips_per_time     0.119769
# 11                          day            revenue_per_time     0.124775
# 12                          day                    avg_temp     0.238300
# 13                          day                    avg_wind    -0.173720
# 14                          day                    avg_rain    -0.101706
# 15                          day                avg_distance     0.060779
# 16                          day                   innerCity     0.082315
# 17                          day                    is_rainy    -0.079474
# 18                          day                    is_windy    -0.139477
# 19                         hour              trips_per_time     0.250862
# 20                         hour            revenue_per_time     0.241281
# 21                         hour                    avg_temp     0.144561
# 22                         hour                    avg_wind     0.105368
# 23                         hour                   innerCity     0.192753
# 24                         hour    avg_dist_from_center_end     0.108112
# 25                         hour                 is_peaktime    -0.062898
# 26                         hour                     is_dark    -0.113908
# 27               trips_per_time            revenue_per_time     0.978444
# 28               trips_per_time                    avg_temp     0.542163
# 29               trips_per_time                    avg_wind     0.180100
# 30               trips_per_time                    avg_rain    -0.089665
# 31               trips_per_time                avg_distance     0.059868
# 32               trips_per_time                   innerCity     0.856237
# 33               trips_per_time               innerCityMean     0.108047
# 34               trips_per_time  avg_dist_from_center_start     0.151340
# 35               trips_per_time                  is_weekday     0.096140
# 36               trips_per_time                 is_peaktime     0.413714
# 37               trips_per_time                     is_dark    -0.599289
# 38               trips_per_time                    is_rainy    -0.072814
# 39             revenue_per_time                    avg_temp     0.563719
# 40             revenue_per_time                    avg_wind     0.185292
# 41             revenue_per_time                    avg_rain    -0.094764
# 42             revenue_per_time                avg_distance     0.070277
# 43             revenue_per_time                   innerCity     0.833517
# 44             revenue_per_time               innerCityMean     0.105005
# 45             revenue_per_time  avg_dist_from_center_start     0.157198
# 46             revenue_per_time                  is_weekday     0.063564
# 47             revenue_per_time                 is_peaktime     0.405242
# 48             revenue_per_time                     is_dark    -0.614354
# 49             revenue_per_time                    is_rainy    -0.072929
# 50             revenue_per_time                    is_windy    -0.053756
# 51                     avg_temp                    avg_wind     0.093178
# 52                     avg_temp                avg_distance     0.154338
# 53                     avg_temp                   innerCity     0.415997
# 54                     avg_temp  avg_dist_from_center_start     0.169383
# 55                     avg_temp    avg_dist_from_center_end     0.151605
# 56                     avg_temp                 is_peaktime     0.101324
# 57                     avg_temp                     is_dark    -0.290009
# 58                     avg_temp                    is_windy    -0.077026
# 59                     avg_wind                    avg_rain     0.141413
# 60                     avg_wind                avg_distance    -0.107646
# 61                     avg_wind                   innerCity     0.194266
# 62                     avg_wind               innerCityMean     0.093713
# 63                     avg_wind                  is_weekday     0.123646
# 64                     avg_wind                 is_peaktime     0.118637
# 65                     avg_wind                     is_dark    -0.331892
# 66                     avg_wind                    is_rainy     0.080075
# 67                     avg_wind                    is_windy     0.434965
# 68                     avg_rain                avg_distance    -0.102766
# 69                     avg_rain                   innerCity    -0.054417
# 70                     avg_rain                 is_peaktime     0.051342
# 71                     avg_rain                     is_dark    -0.074437
# 72                     avg_rain                    is_rainy     0.684100
# 73                     avg_rain                    is_windy     0.125221
# 74                 avg_distance               innerCityMean    -0.111291
# 75                 avg_distance  avg_dist_from_center_start     0.186002
# 76                 avg_distance    avg_dist_from_center_end     0.238731
# 77                 avg_distance                  is_weekday    -0.076176
# 78                 avg_distance                 is_peaktime     0.103332
# 79                 avg_distance                     is_dark     0.123963
# 80                 avg_distance                    is_rainy    -0.089248
# 81                 avg_distance                    is_windy    -0.110579
# 82                    innerCity               innerCityMean     0.545902
# 83                    innerCity  avg_dist_from_center_start    -0.135608
# 84                    innerCity    avg_dist_from_center_end    -0.088154
# 85                    innerCity                  is_weekday     0.168511
# 86                    innerCity                 is_peaktime     0.313531
# 87                    innerCity                     is_dark    -0.539793
# 88                    innerCity                    is_rainy    -0.056178
# 89                innerCityMean  avg_dist_from_center_start    -0.521364
# 90                innerCityMean    avg_dist_from_center_end    -0.195793
# 91                innerCityMean                  is_weekday     0.106952
# 92                innerCityMean                     is_dark    -0.117887
# 93   avg_dist_from_center_start    avg_dist_from_center_end     0.541276
# 94   avg_dist_from_center_start                 is_peaktime     0.137038
# 95   avg_dist_from_center_start                     is_dark    -0.094295
# 96     avg_dist_from_center_end                     is_dark     0.051498
# 97                  is_peaktime                     is_dark    -0.393711
# 98                  is_peaktime                    is_rainy     0.050139
# 99                      is_dark                    is_rainy    -0.071012
# 100                     is_dark                    is_windy    -0.077651
# 101                    is_rainy                    is_windy     0.065686

# %%
# DÜSSELDORF, PEARSON CORRELATION
prep_du_pe = show_high_corr(du, 0.05, -0.05, "pearson")
prep_du_pe
# Out:
#                           col1                        col2  correlation
# 0                        month              trips_per_time     0.519501
# 1                        month            revenue_per_time     0.468922
# 2                        month                    avg_temp     0.608237
# 3                        month                    avg_wind    -0.145120
# 4                        month                avg_distance    -0.075954
# 5                        month                   innerCity     0.337312
# 6                        month  avg_dist_from_center_start    -0.090167
# 7                        month    avg_dist_from_center_end    -0.098002
# 8                        month                  is_weekday    -0.053011
# 9                        month                 is_peaktime    -0.119233
# 10                       month                     is_dark     0.126424
# 11                       month                    is_windy    -0.150729
# 12                         day              trips_per_time     0.164119
# 13                         day            revenue_per_time     0.161331
# 14                         day                    avg_temp     0.264434
# 15                         day                    avg_wind    -0.133001
# 16                         day                    avg_rain    -0.052836
# 17                         day                   innerCity     0.121178
# 18                         day  avg_dist_from_center_start    -0.104210
# 19                         day    avg_dist_from_center_end    -0.090339
# 20                         day                    is_rainy    -0.057429
# 21                         day                    is_windy    -0.144650
# 22                        hour              trips_per_time     0.133344
# 23                        hour            revenue_per_time     0.099583
# 24                        hour                    avg_temp     0.145013
# 25                        hour                   innerCity     0.194702
# 26                        hour               innerCityMean     0.090730
# 27                        hour                 is_peaktime    -0.125224
# 28              trips_per_time            revenue_per_time     0.944414
# 29              trips_per_time                    avg_temp     0.679965
# 30              trips_per_time                    avg_rain    -0.051334
# 31              trips_per_time                   innerCity     0.697039
# 32              trips_per_time                  is_weekday    -0.081253
# 33              trips_per_time                 is_peaktime     0.188006
# 34              trips_per_time                     is_dark    -0.250152
# 35              trips_per_time                    is_rainy    -0.060628
# 36              trips_per_time                    is_windy    -0.101921
# 37            revenue_per_time                    avg_temp     0.664886
# 38            revenue_per_time                    avg_rain    -0.054344
# 39            revenue_per_time                   innerCity     0.670659
# 40            revenue_per_time    avg_dist_from_center_end    -0.051234
# 41            revenue_per_time                  is_weekday    -0.113975
# 42            revenue_per_time                 is_peaktime     0.203410
# 43            revenue_per_time                     is_dark    -0.281216
# 44            revenue_per_time                    is_rainy    -0.069348
# 45            revenue_per_time                    is_windy    -0.108389
# 46                    avg_temp                   innerCity     0.477565
# 47                    avg_temp  avg_dist_from_center_start    -0.052261
# 48                    avg_temp    avg_dist_from_center_end    -0.076828
# 49                    avg_temp                  is_weekday    -0.072729
# 50                    avg_temp                     is_dark    -0.229975
# 51                    avg_temp                    is_rainy    -0.066826
# 52                    avg_temp                    is_windy    -0.105869
# 53                    avg_wind                    avg_rain     0.092988
# 54                    avg_wind                avg_distance     0.058172
# 55                    avg_wind  avg_dist_from_center_start     0.098470
# 56                    avg_wind    avg_dist_from_center_end     0.063685
# 57                    avg_wind                 is_peaktime     0.139899
# 58                    avg_wind                     is_dark    -0.291756
# 59                    avg_wind                    is_rainy     0.108989
# 60                    avg_wind                    is_windy     0.595965
# 61                    avg_rain                    is_rainy     0.690253
# 62                    avg_rain                    is_windy     0.091647
# 63                avg_distance               innerCityMean    -0.094593
# 64                avg_distance  avg_dist_from_center_start     0.099569
# 65                avg_distance    avg_dist_from_center_end     0.083273
# 66                avg_distance                 is_peaktime     0.085988
# 67                avg_distance                     is_dark    -0.082884
# 68                   innerCity               innerCityMean     0.436868
# 69                   innerCity  avg_dist_from_center_start    -0.117882
# 70                   innerCity    avg_dist_from_center_end    -0.085854
# 71                   innerCity                  is_weekday    -0.147580
# 72                   innerCity                 is_peaktime     0.091336
# 73                   innerCity                     is_dark    -0.138269
# 74                   innerCity                    is_windy    -0.067483
# 75               innerCityMean  avg_dist_from_center_start    -0.245917
# 76               innerCityMean    avg_dist_from_center_end    -0.133067
# 77               innerCityMean                  is_weekday    -0.113028
# 78               innerCityMean                 is_peaktime    -0.065493
# 79               innerCityMean                     is_dark     0.053828
# 80  avg_dist_from_center_start    avg_dist_from_center_end     0.920410
# 81  avg_dist_from_center_start                     is_dark    -0.064979
# 82  avg_dist_from_center_start                    is_rainy     0.063320
# 83  avg_dist_from_center_start                    is_windy     0.093353
# 84    avg_dist_from_center_end                    is_rainy     0.061583
# 85    avg_dist_from_center_end                    is_windy     0.070570
# 86                 is_peaktime                     is_dark    -0.364702
# 87                 is_peaktime                    is_windy     0.054423
# 88                     is_dark                    is_windy    -0.091119
# 89                    is_rainy                    is_windy     0.159569

# %%
# DÜSSELDORF, SPEARMAN CORRELATION
prep_du_sp = show_high_corr(du, 0.05, -0.05, "spearman")
prep_du_sp
# Out:
#                            col1                        col2  correlation
# 0                         month              trips_per_time     0.567465
# 1                         month            revenue_per_time     0.520294
# 2                         month                    avg_temp     0.633726
# 3                         month                    avg_wind    -0.109163
# 4                         month                avg_distance    -0.055085
# 5                         month                   innerCity     0.360803
# 6                         month               innerCityMean     0.177802
# 7                         month  avg_dist_from_center_start     0.134077
# 8                         month    avg_dist_from_center_end     0.124602
# 9                         month                  is_weekday    -0.056881
# 10                        month                 is_peaktime    -0.111921
# 11                        month                     is_dark     0.124773
# 12                        month                    is_windy    -0.144326
# 13                          day              trips_per_time     0.143165
# 14                          day            revenue_per_time     0.151557
# 15                          day                    avg_temp     0.263089
# 16                          day                    avg_wind    -0.083591
# 17                          day                    avg_rain    -0.102576
# 18                          day                   innerCity     0.110775
# 19                          day               innerCityMean     0.069614
# 20                          day                    is_rainy    -0.057982
# 21                          day                    is_windy    -0.142657
# 22                         hour              trips_per_time     0.124287
# 23                         hour            revenue_per_time     0.079198
# 24                         hour                    avg_temp     0.137051
# 25                         hour                   innerCity     0.204836
# 26                         hour               innerCityMean     0.169438
# 27                         hour  avg_dist_from_center_start    -0.100714
# 28                         hour    avg_dist_from_center_end    -0.081709
# 29                         hour                 is_peaktime    -0.150472
# 30               trips_per_time            revenue_per_time     0.949076
# 31               trips_per_time                    avg_temp     0.671488
# 32               trips_per_time                    avg_rain    -0.093836
# 33               trips_per_time                avg_distance     0.110632
# 34               trips_per_time                   innerCity     0.615744
# 35               trips_per_time               innerCityMean     0.339376
# 36               trips_per_time  avg_dist_from_center_start     0.146273
# 37               trips_per_time    avg_dist_from_center_end     0.057137
# 38               trips_per_time                  is_weekday    -0.056028
# 39               trips_per_time                 is_peaktime     0.209517
# 40               trips_per_time                     is_dark    -0.308852
# 41               trips_per_time                    is_rainy    -0.070393
# 42               trips_per_time                    is_windy    -0.158290
# 43             revenue_per_time                    avg_temp     0.655291
# 44             revenue_per_time                    avg_rain    -0.100974
# 45             revenue_per_time                avg_distance     0.118202
# 46             revenue_per_time                   innerCity     0.585768
# 47             revenue_per_time               innerCityMean     0.317097
# 48             revenue_per_time  avg_dist_from_center_start     0.129033
# 49             revenue_per_time                  is_weekday    -0.069368
# 50             revenue_per_time                 is_peaktime     0.213427
# 51             revenue_per_time                     is_dark    -0.327190
# 52             revenue_per_time                    is_rainy    -0.079212
# 53             revenue_per_time                    is_windy    -0.151268
# 54                     avg_temp                    avg_wind     0.067738
# 55                     avg_temp                    avg_rain    -0.103934
# 56                     avg_temp                avg_distance     0.058186
# 57                     avg_temp                   innerCity     0.461194
# 58                     avg_temp               innerCityMean     0.242937
# 59                     avg_temp  avg_dist_from_center_start     0.135765
# 60                     avg_temp    avg_dist_from_center_end     0.059912
# 61                     avg_temp                  is_weekday    -0.065411
# 62                     avg_temp                     is_dark    -0.220534
# 63                     avg_temp                    is_rainy    -0.063012
# 64                     avg_temp                    is_windy    -0.115316
# 65                     avg_wind                    avg_rain     0.080399
# 66                     avg_wind  avg_dist_from_center_start     0.082187
# 67                     avg_wind                 is_peaktime     0.143846
# 68                     avg_wind                     is_dark    -0.318820
# 69                     avg_wind                    is_rainy     0.062687
# 70                     avg_wind                    is_windy     0.345161
# 71                     avg_rain                   innerCity    -0.060598
# 72                     avg_rain                    is_rainy     0.685355
# 73                     avg_rain                    is_windy     0.176690
# 74                 avg_distance  avg_dist_from_center_start     0.140909
# 75                 avg_distance    avg_dist_from_center_end     0.178034
# 76                 avg_distance                 is_peaktime     0.139510
# 77                 avg_distance                     is_dark    -0.093332
# 78                    innerCity               innerCityMean     0.892309
# 79                    innerCity  avg_dist_from_center_start    -0.288148
# 80                    innerCity    avg_dist_from_center_end    -0.132481
# 81                    innerCity                  is_weekday    -0.120615
# 82                    innerCity                 is_peaktime     0.066053
# 83                    innerCity                     is_dark    -0.148311
# 84                    innerCity                    is_rainy    -0.050582
# 85                    innerCity                    is_windy    -0.085214
# 86                innerCityMean  avg_dist_from_center_start    -0.461123
# 87                innerCityMean    avg_dist_from_center_end    -0.206932
# 88                innerCityMean                  is_weekday    -0.111089
# 89                innerCityMean                     is_dark    -0.057278
# 90                innerCityMean                    is_windy    -0.054752
# 91   avg_dist_from_center_start    avg_dist_from_center_end     0.492323
# 92   avg_dist_from_center_start                  is_weekday     0.143554
# 93   avg_dist_from_center_start                 is_peaktime     0.099070
# 94   avg_dist_from_center_start                     is_dark    -0.104899
# 95   avg_dist_from_center_start                    is_windy     0.054687
# 96     avg_dist_from_center_end                  is_weekday     0.107549
# 97     avg_dist_from_center_end                     is_dark     0.051129
# 98                  is_peaktime                     is_dark    -0.364702
# 99                  is_peaktime                    is_windy     0.054423
# 100                     is_dark                    is_windy    -0.091119
# 101                    is_rainy                    is_windy     0.159569

# %% [markdown]
# similar to above, but:
# - month is highly correlated with num of trips (**target**), revenue and avg temp
# - hour is highly correlated with num of trips (**target**)
# - day is slightly correlated with num of trips (**target**), revenue and avg temp
# - num of trips (**target**) is highly correlated with revenue and temp

# %% [markdown]
# **condensed for target variable: correlation of features with target variable on prepared data set**

# %%
target_corr_br = pd.DataFrame(data=pd.DataFrame(data=br.corr(method="pearson"))["trips_per_time"]).rename(columns={"trips_per_time": "pearson"})
target_corr_br["spearman"] = pd.DataFrame(data=br.corr(method="spearman"))["trips_per_time"]
target_corr_br
# Out:
#                              pearson  spearman
# month                       0.338867  0.315185
# day                         0.117279  0.119769
# hour                        0.217539  0.250862
# trips_per_time              1.000000  1.000000
# revenue_per_time            0.934448  0.978444
# avg_temp                    0.561897  0.542163
# avg_wind                    0.115841  0.180100
# avg_rain                   -0.079403 -0.089665
# avg_distance               -0.016287  0.059868
# innerCity                   0.836820  0.856237
# innerCityMean               0.005871  0.108047
# avg_dist_from_center_start -0.002264  0.151340
# avg_dist_from_center_end   -0.072669  0.032474
# is_weekday                  0.110065  0.096140
# is_peaktime                 0.410457  0.413714
# is_dark                    -0.535369 -0.599289
# is_rainy                   -0.078488 -0.072814
# is_windy                   -0.063367 -0.049957

# %%
target_corr_du = pd.DataFrame(data=pd.DataFrame(data=du.corr(method="pearson"))["trips_per_time"]).rename(columns={"trips_per_time": "pearson"})
target_corr_du["spearman"] = pd.DataFrame(data=du.corr(method="spearman"))["trips_per_time"]
target_corr_du
# Out:
#                              pearson  spearman
# month                       0.519501  0.567465
# day                         0.164119  0.143165
# hour                        0.133344  0.124287
# trips_per_time              1.000000  1.000000
# revenue_per_time            0.944414  0.949076
# avg_temp                    0.679965  0.671488
# avg_wind                    0.007316  0.034251
# avg_rain                   -0.051334 -0.093836
# avg_distance               -0.005307  0.110632
# innerCity                   0.697039  0.615744
# innerCityMean               0.001427  0.339376
# avg_dist_from_center_start -0.019572  0.146273
# avg_dist_from_center_end   -0.047424  0.057137
# is_weekday                 -0.081253 -0.056028
# is_peaktime                 0.188006  0.209517
# is_dark                    -0.250152 -0.308852
# is_rainy                   -0.060628 -0.070393
# is_windy                   -0.101921 -0.158290

# %% [markdown]
# ### Suitable features
# #### those features from pepared data set with corr > 0.05 or < -0.05 and which are assumed to have impact on rental, sorted by assumed impact on rental demand
# - temp
# - month
# - hour
# - day
# - wind
# - rain
# - distance from city center
# - weekday

# %% [markdown]
# ***
# ## Select features

# %%
# all possible pre-selected features
# ["month", "day", "hour", "avg_temp", "avg_wind", "avg_rain", "avg_distance", "avg_dist_from_center_end", "is_weekday", "innerCityMean", is_peaktime", "is_dark", "is_rainy", "is_windy"]

# %% [markdown]
# ##### split into weekday, weekend and combined

# %%
x_br_weekday = br[br["is_weekday"]==True][["month", "day", "hour", "avg_temp", "avg_wind", "avg_rain", "avg_distance", "avg_dist_from_center_end", "is_peaktime", "is_dark","is_rainy", "is_windy"]]
x_br_weekend = br[br["is_weekday"]==False][["month", "day", "hour", "avg_temp", "avg_wind", "avg_rain","avg_distance", "avg_dist_from_center_end", "is_peaktime", "is_dark","is_rainy", "is_windy"]]
x_br_full    = br[["month", "day", "hour", "avg_temp", "avg_wind", "avg_rain", "avg_distance", "avg_dist_from_center_end", "is_weekday", "is_peaktime", "is_dark","is_rainy", "is_windy"]]
y_br_weekday = br[br["is_weekday"]==True]["trips_per_time"]
y_br_weekend = br[br["is_weekday"]==False]["trips_per_time"]
y_br_full = br["trips_per_time"]

# %% [markdown]
# ##### automatically select k best features (features n=9)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression, mutual_info_regression
from sklearn.preprocessing import MinMaxScaler

# %%
br_new_wd = SelectKBest(f_regression, k=3).fit_transform(x_br_weekend,y_br_weekend)
# br_new_wd = SelectKBest(mutual_info_regression, k=3).fit_transform(x_br_weekend,y_br_weekend)
pd.DataFrame(br_new_wd)
# Out:
#            0      1      2
# 0      -1.75  False   True
# 1       -1.5  False   True
# 2       -1.5  False   True
# 3       -1.3  False   True
# 4       -1.3  False   True
# ..       ...    ...    ...
# 976  21.3577  False  False
# 977     19.8  False   True
# 978  17.7917  False   True
# 979     16.4  False   True
# 980  17.7625  False   True
#
# [981 rows x 3 columns]

# %% [markdown]
# #### results from playing around with x_br_weekday, x_br_weekend, x_br_full with k = 1,...,8
# ##### best k features from k=1 to k=8 on weekdays
# - hour
# - hour, temp
# - hour, temp, avg_dist_from_center_end
# - hour, temp, avg_distance, avg_dist_from_center_end
# - hour, temp, avg_distance, avg_wind, avg_dist_from_center_end
# - month, hour, temp, avg_distance, avg_wind, avg_dist_from_center_end
# - month, hour, temp, avg_distance, avg_wind, avg_rain, avg_dist_from_center_end
# - month, day, hour, temp, avg_distance, avg_wind, avg_rain, avg_dist_from_center_end
#
# ##### best k features from k=1 to k=8 on weekends
# - temp
# - hour, temp
# - hour, temp, avg_distance_from_city_center_end
# - day, hour, temp, avg_distance_from_city_center_end
# - day, hour, temp, avg_distance, avg_distance_from_city_center_end
# - month, day, hour, temp, avg_distance, avg_distance_from_city_center_end
# - month, day, hour, temp, wind, avg_distance, avg_distance_from_city_center_end
# - month, day, hour, temp, wind, rain, avg_distance, avg_distance_from_city_center_end
#
# ##### best k features from k=1 to k=8 on all days
# - hour
# - hour, temp
# - hour, temp, avg_dist_from_center_end
# - hour, temp, avg_distance, avg_dist_from_center_end
# - hour, temp, avg_distance, avg_wind, avg_dist_from_center_end
# - month, hour, temp, avg_distance, avg_wind, avg_dist_from_center_end
# - month, hour, temp, avg_distance, avg_wind, avg_dist_from_center_end, is_weekday
# - month, day, hour, temp, avg_distance, avg_wind, avg_dist_from_center_end, is_weekday

# %% [markdown]
# ##### for both weekday and weekend  temperature the 3 most important features seem to be hour, temp and avg_dist_from_center_end

# %% [markdown]
# ***
# # Prediction

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ##### selected features for prediction

# %%
# all possible pre-selected features
# ["month", "day", "hour", "avg_temp", "avg_wind", "avg_rain", "avg_distance", "avg_dist_from_center_end", "is_weekday", "innerCityMean", is_peaktime", "is_dark", "is_rainy", "is_windy"]

# %%
# SELECT FEATURES HERE
city = "Bremen"
# city = "Düsseldorf"

if city == "Bremen":
    features = ["hour", "month", "avg_temp","avg_wind","is_weekday","innerCityMean", "is_peaktime", "is_dark"]
    X_full = br[features]
    y_full = br["trips_per_time"]
else:
    features = ["hour", "month", "avg_temp","avg_wind","is_weekday", "innerCityMean","is_peaktime", "is_dark"]
    X_full = du[features]
    y_full = du["trips_per_time"]

# %%
SPLIT_TRAIN = 0.7
X_train, X_test, y_train, y_test = train_test_split(X_full, y_full, random_state=0, train_size=SPLIT_TRAIN)

# %%
# SPLIT_TRAIN = 0.5
# SPLIT_VALIDATION = 0.3
# SPLIT_TEST = 0.2
# # generate Training set with 50% of orig. data, and 50% rest for validation and test
# X_train, X_split, y_train, y_split = train_test_split(X_full, y_full, random_state=0, train_size=SPLIT_TRAIN)

# # split the other 50% of orig. data:
# # 0.3/0.5 = 0.6, 0.6 * 50% = 30% for Validation set, and 0.4 * 50% = 20% for Test set
# X_valid, X_test, y_valid, y_test = train_test_split(X_split, y_split, random_state=0, train_size=SPLIT_VALIDATION/SPLIT_TRAIN)

# %% [markdown]
# #### visualized target values, train and test

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(20, 10))
sns.lineplot(data=y_train, ax=ax1)
sns.lineplot(data=y_test, ax=ax2)

# %%
from sklearn.experimental import enable_hist_gradient_boosting  # noqa
from sklearn.ensemble import HistGradientBoostingRegressor, GradientBoostingRegressor

# %% [markdown]
# ## Model 1: Histogram Gradient Boosting regression

# %%
## Histogram gradient Boosting
histgrad = HistGradientBoostingRegressor(max_iter=72).fit(X_train, y_train)

# prediction on test data
y_pred_histgrad = histgrad.predict(X_test)

# evaluate
r2_histgrad = r2_score(y_test, y_pred_histgrad)
MAE_histgrad =  mean_absolute_error(y_test, y_pred_histgrad)
MSE_histgrad = mean_squared_error(y_test, y_pred_histgrad, squared = True)
RMSE_histgrad = mean_squared_error(y_test, y_pred_histgrad, squared = False)

print (f'Histogram Gradient Boosting Regression, {TIME_FRAME}ly')
print ("Training splits: Training set ", SPLIT_TRAIN, ", Test set: ",1-SPLIT_TRAIN)
print ("Features: ", features)
print ('The R^2  of histogram gradient boosting regression is: ', r2_histgrad)
print ('The MAE  of histogram gradient boosting regression is: ', MAE_histgrad)
print ('The MSE  of histogram gradient boosting regression is: ', MSE_histgrad)
print ('The RMSE of histogram gradient boosting regression is: ', RMSE_histgrad, "\n\n")
# Out:
# Histogram Gradient Boosting Regression, hourly
# Training splits: Training set  0.7 , Test set:  0.30000000000000004
# Features:  ['hour', 'month', 'avg_temp', 'avg_wind', 'is_weekday', 'innerCityMean', 'is_peaktime', 'is_dark']
# The R^2  of histogram gradient boosting regression is:  0.7747155489861347
# The MAE  of histogram gradient boosting regression is:  4.599680670688424
# The MSE  of histogram gradient boosting regression is:  40.45303567166355
# The RMSE of histogram gradient boosting regression is:  6.360270094238416

# %% [markdown]
# ## Model 2: Gradient Boosting Regression

# %%
## Gradient Boosting
grad = GradientBoostingRegressor(n_estimators=450, loss='ls').fit(X_train, y_train)

# prediction on test data
y_pred_grad  = grad.predict(X_test)

# evaluate
r2_grad = r2_score(y_test, y_pred_grad)
MAE_grad =  mean_absolute_error(y_test, y_pred_grad)
MSE_grad = mean_squared_error(y_test, y_pred_grad, squared = True)
RMSE_grad = mean_squared_error(y_test, y_pred_grad, squared = False)

print (f'Gradient Boosting Regression, {TIME_FRAME}ly')
print ("Training splits: Training set ", SPLIT_TRAIN, ", Test set: ",1-SPLIT_TRAIN)
print ("Features: ", features)
print ('The R^2  of gradient boosting regression is: ', r2_grad)
print ('The MAE  of gradient boosting regression is: ', MAE_grad)
print ('The MSE  of gradient boosting regression is: ', MSE_grad)
print ('The RMSE of gradient boosting regression is: ', RMSE_grad)
# Out:
# Gradient Boosting Regression, hourly
# Training splits: Training set  0.7 , Test set:  0.30000000000000004
# Features:  ['hour', 'month', 'avg_temp', 'avg_wind', 'is_weekday', 'innerCityMean', 'is_peaktime', 'is_dark']
# The R^2  of gradient boosting regression is:  0.7780953598448805
# The MAE  of gradient boosting regression is:  4.597040901797884
# The MSE  of gradient boosting regression is:  39.846142436835244
# The RMSE of gradient boosting regression is:  6.312380092867922

# %%
def plot_results(predictions):
    fig, axes = plt.subplots(nrows=len(features), ncols=1, figsize=(15, 40))

    for i in range(0,len(features)):
        axes[i].scatter(X_train[features[i]],y_train, marker='x', color='b')
        axes[i].scatter(X_test[features[i]],predictions, marker='x', color='r')
        axes[i].set_xlabel(features[i])
        axes[i].set_ylabel("Demand")
        axes[i].legend(["Training Set", 'Prediction Set'])

# %% [markdown]
# ## Model 3: Linear regression

# %%
# fit model on training data
model_lin = LinearRegression(normalize = True)
model_lin.fit(X_train, y_train)

# prediction on test data
y_pred_lin = model_lin.predict(X_test)

# evaluate
r2_lin = r2_score(y_test, y_pred_lin)
MAE_lin =  mean_absolute_error(y_test, y_pred_lin)
MSE_lin = mean_squared_error(y_test, y_pred_lin, squared = True)
RMSE_lin = mean_squared_error(y_test, y_pred_lin, squared = False)

print (f'Linear Regression, {TIME_FRAME}ly')
print ("Training splits: Training set ", SPLIT_TRAIN, ", Test set: ",1-SPLIT_TRAIN)
print ("Features: ", features)
print ('The R^2  of linear regression is: ', r2_lin)
print ('The MAE  of linear regression is: ', MAE_lin)
print ('The MSE  of linear regression is: ', MSE_lin)
print ('The RMSE of linear regression is: ', RMSE_lin)
print("Coefficients ", model_lin.coef_, "\nIntercept ", model_lin.intercept_ )
plot_results(y_pred_lin)
# Out:
# Linear Regression, hourly
# Training splits: Training set  0.7 , Test set:  0.30000000000000004
# Features:  ['hour', 'month', 'avg_temp', 'avg_wind', 'is_weekday', 'innerCityMean', 'is_peaktime', 'is_dark']
# The R^2  of linear regression is:  0.5909157289911442
# The MAE  of linear regression is:  6.628752559921808
# The MSE  of linear regression is:  73.45691428486211
# The RMSE of linear regression is:  8.57070092144523
# Coefficients  [ 0.32181577  1.33323031  0.61565185 -0.12674431  2.728544    2.31938267
#   7.63333672 -8.5254293 ]
# Intercept  0.12861161103040786

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

# %% [markdown]
# ## Model 4: polynomial regression

# %% [markdown]
# ### select best degree via grid search and cross validation

# %%
# using grid search to find best degree by the metrics r2 and MAE
# https://scikit-learn.org/stable/modules/model_evaluation.html
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
# https://scikit-learn.org/stable/modules/grid_search.html
param_grid = [
    {'poly__degree': [1, 2, 3, 4, 5, 6, 7, 8]}
  ]
  
pipeline_poly = Pipeline(steps=[('poly', PolynomialFeatures()), ('linear', LinearRegression(normalize = True))])
Poly_GS = GridSearchCV(pipeline_poly, param_grid, cv=5,
                           scoring='r2',
                           return_train_score=True)
Poly_GS.fit(np.array(X_train).reshape(y_train.shape[0],-1), y_train)

poly2 = PolynomialFeatures(degree = Poly_GS.best_params_["poly__degree"])
x_poly2 = poly2.fit_transform(np.array(X_train).reshape(y_train.shape[0],-1))
PolyRegression = LinearRegression(normalize = True)
PolyRegression.fit(x_poly2, y_train)
# Out:
# LinearRegression(normalize=True)

# %% [markdown]
# ### evaluate model

# %%
# prediction on test data
y_pred_poly = PolyRegression.predict(poly2.fit_transform(np.array(X_test).reshape(y_test.shape[0],-1)))

# evaluate
r2_poly = r2_score(y_test, y_pred_poly)
MAE_poly =  mean_absolute_error(y_test, y_pred_poly)
MSE_poly = mean_squared_error(y_test, y_pred_poly, squared = True)
RMSE_poly = mean_squared_error(y_test, y_pred_poly, squared = False)

print (f'Polynomial Regression, {TIME_FRAME}ly, degree: {Poly_GS.best_params_["poly__degree"]}')
print ("Training splits: Training set ", SPLIT_TRAIN, ", Test set: ",1-SPLIT_TRAIN)
print ("Features: ", features)
print ('The R^2  of polynomial regression is: ', r2_poly)
print ('The MAE  of polynomial regression is: ', MAE_poly)
print ('The MSE  of polynomial regression is: ', MSE_poly)
print ('The RMSE of polynomial regression is: ', RMSE_poly)
print("Coefficients ", PolyRegression.coef_, "\nIntercept ", PolyRegression.intercept_ )
plot_results(y_pred1)
# Out:
# Polynomial Regression, hourly, degree: 4
# Training splits: Training set  0.7 , Test set:  0.30000000000000004
# Features:  ['hour', 'month', 'avg_temp', 'avg_wind', 'is_weekday', 'innerCityMean', 'is_peaktime', 'is_dark']
# The R^2  of polynomial regression is:  0.734229316246752
# The MAE  of polynomial regression is:  5.14412217335998
# The MSE  of polynomial regression is:  47.722916082170535
# The RMSE of polynomial regression is:  6.9081774790584625
# Coefficients  [-1.21996233e-10  9.42124455e-01 -1.24234365e+01 -2.34574040e+00
#   3.62909758e+00 -5.61191732e+00 -1.12434062e+02  8.46713930e+01
#  -1.29161311e+00  2.51290327e-01 -1.36906178e+00  2.20720395e-01
#   9.83965765e-02  1.04377491e+00  9.84550126e+00 -2.51032846e+01
#  -8.52354018e-01 -2.17217660e+00  2.83350707e+00  2.91804190e+00
#   2.01575043e+00  5.41173930e+01  8.05696308e-01  5.50999108e+00
#  -1.41199969e-01 -1.12796276e+00 -3.13410818e-01  3.70139998e+00
#  -1.01004488e-01  8.94065055e-01 -8.73111195e-02 -1.19485684e+00
#  -1.04570108e+01 -9.03398125e+00 -2.71845130e+00 -5.61191731e+00
#   1.16527645e+01 -2.06943454e+01  1.78495727e+00 -2.11007729e+02
#   1.43210728e+02  6.86733273e+01  8.46713930e+01 -2.22050370e+00
#  -1.29161311e+00 -3.19494579e-02  8.46048539e-02 -3.88357320e-04
#   2.26143998e-02 -5.44352124e-02 -1.45665631e-02  2.91827381e+00
#   6.14854505e-02  1.44033945e-01 -4.34101557e-02 -3.71801221e-02
#   3.48971378e-01 -9.96437651e-01 -1.93884692e+00  3.48152750e-01
#   3.63104613e-03  2.69111771e-02 -1.71185031e-02 -7.12147984e-02
#   1.32311573e-01 -1.96420350e-01 -1.15697931e-01 -1.74106233e-01
#  -4.32977178e-01  1.71659676e+00  2.10939886e-01  1.04377491e+00
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4389         y = np.ma.ravel(y)
#    4390         if x.size != y.size:
# -> 4391             raise ValueError("x and y must be the same size")
#    4392
#    4393         if s is None:
#
# ValueError: x and y must be the same size

# %% [markdown]
# ## Model 5: Ridge regression

# %%
from sklearn.linear_model import Ridge

# %% [markdown]
# ### select best params via grid search and cross validation
# Since the best polynomial degree seems to be around 4, we now vary the degree around 4 with different regularization params

# %%
param_grid = {
    'poly__degree': [3, 4, 5, 6],
    'ridge__alpha': [1, 0.1, 0.01, 0.001, 0.0001],
    }

pipeline_ridge = Pipeline(steps=[('poly', PolynomialFeatures()), ('ridge', Ridge(random_state=0, normalize = True))])

Ridge_GS = GridSearchCV(pipeline_ridge, param_grid, cv=5,
                           scoring='neg_mean_absolute_error')
Ridge_GS.fit(np.array(X_train).reshape(y_train.shape[0],-1), y_train)

# train model with best params on training set
poly_ridge = PolynomialFeatures(degree = Ridge_GS.best_params_["poly__degree"])
x_poly_ridge = poly_ridge.fit_transform(np.array(X_train).reshape(y_train.shape[0],-1))
Ridgeregression = Ridge(**Ridge_GS.best_estimator_.named_steps['ridge'].get_params())
Ridgeregression.fit(x_poly_ridge,y_train)
# Out:
# Ridge(alpha=0.001, normalize=True, random_state=0)

# %% [markdown]
# ### evaluate model

# %%
# prediction on test data
y_pred_ridge = Ridgeregression.predict(poly_ridge.fit_transform(np.array(X_test).reshape(y_test.shape[0],-1)))

# evaluate
r2_ridge = r2_score(y_test, y_pred_ridge)
MAE_ridge =  mean_absolute_error(y_test, y_pred_ridge)
MSE_ridge = mean_squared_error(y_test, y_pred_ridge, squared = True)
RMSE_ridge = mean_squared_error(y_test, y_pred_ridge, squared = False)

print (f'Ridge Regression, {TIME_FRAME}ly')
print('Params: ', Ridge_GS.best_params_)
print ("Training splits: Training set ", SPLIT_TRAIN, ", Test set: ",1-SPLIT_TRAIN)
print ("Features: ", features)
print ('The R^2  of ridge regression is: ', r2_ridge)
print ('The MAE  of ridge regression is: ', MAE_ridge)
print ('The MSE  of ridge regression is: ', MSE_ridge)
print ('The RMSE of ridge regression is: ', RMSE_ridge)
print("Coefficients ", Ridgeregression.coef_, "\nIntercept ", Ridgeregression.intercept_ )
plot_results(y_pred_ridge)
# Out:
# Ridge Regression, hourly
# Params:  {'poly__degree': 4, 'ridge__alpha': 0.001}
# Training splits: Training set  0.7 , Test set:  0.30000000000000004
# Features:  ['hour', 'month', 'avg_temp', 'avg_wind', 'is_weekday', 'innerCityMean', 'is_peaktime', 'is_dark']
# The R^2  of ridge regression is:  0.7351828984837733
# The MAE  of ridge regression is:  4.978964511146412
# The MSE  of ridge regression is:  47.551686793702196
# The RMSE of ridge regression is:  6.895773110660051
# Coefficients  [ 0.00000000e+00  2.92516904e-01  6.79625996e-01  1.25985328e-01
#  -4.60123655e-01 -2.42840193e+00  5.07618363e+00  3.24073327e+00
#   2.65298474e+00  2.81199927e-02  5.70070161e-02  3.91520278e-02
#   4.84206207e-02  2.59750004e-01  5.70138689e-01 -4.97472942e-01
#  -5.34817593e-01  7.14887077e-02 -7.08346780e-02 -6.01644945e-02
#   6.48423076e-01  3.22362924e+00  9.83454845e-01 -2.35896223e-01
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-3c33a2c21fa2> in <module>
#      17 print ('The RMSE of ridge regression is: ', RMSE_ridge)
#      18 print("Coefficients ", Ridgeregression.coef_, "\nIntercept ", Ridgeregression.intercept_ )
# ---> 19 plot_results(y_pred_ridge)
#
# NameError: name 'plot_results' is not defined

# %% [markdown]
# ## Model 6: Lasso regression

# %%
from sklearn.linear_model import Lasso

# %% [markdown]
# ### select best params via grid search and cross validation
# Since the best polynomial degree seems to be around 4, we now vary the degree around 4 with different regularization params

# %%
param_grid = {
    'poly__degree': [3, 4, 5, 6],
    'lasso__alpha': [1, 0.1, 0.01, 0.001, 0.0001],
    }

pipeline_lasso = Pipeline(steps=[('poly', PolynomialFeatures()), ('lasso', Lasso(random_state=0, normalize = True))])

Lasso_GS = GridSearchCV(pipeline_lasso, param_grid, cv=5,
                           scoring='neg_mean_absolute_error')
Lasso_GS.fit(np.array(X_train).reshape(y_train.shape[0],-1), y_train)

# train model with best params on training set
poly_lasso = PolynomialFeatures(degree = Lasso_GS.best_params_["poly__degree"])
x_poly_lasso = poly_lasso.fit_transform(np.array(X_train).reshape(y_train.shape[0],-1))
Lassoregression = Lasso(**Lasso_GS.best_estimator_.named_steps['lasso'].get_params())
Lassoregression.fit(x_poly_lasso,y_train)
# Out:
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.880827419416164, tolerance: 32.541387014369356
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.29786798826535, tolerance: 32.46600276742945
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 172.09007835511875, tolerance: 32.541387014369356
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 352.69025629770476, tolerance: 32.46600276742945
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86.23840986212599, tolerance: 33.13787982969664
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 119.09141118639673, tolerance: 32.122385098456625
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 103.84104445039702, tolerance: 33.30080425531916
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 433.1045517517632, tolerance: 32.541387014369356
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 763.215148844858, tolerance: 32.46600276742945
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 171.83678081263497, tolerance: 33.13787982969664
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 483.8920632892259, tolerance: 32.122385098456625
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 530.613006155254, tolerance: 33.30080425531916
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19222.01176314459, tolerance: 32.541387014369356
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17457.503087743506, tolerance: 32.46600276742945
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20091.965738006365, tolerance: 33.13787982969664
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18209.800248062056, tolerance: 32.122385098456625
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20819.96644421939, tolerance: 33.30080425531916
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15846.195140593867, tolerance: 32.541387014369356
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17022.442266727543, tolerance: 32.46600276742945
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21440.34469616165, tolerance: 33.13787982969664
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18055.93523039426, tolerance: 32.122385098456625
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14807.247511299276, tolerance: 33.30080425531916
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21890.677839880856, tolerance: 32.541387014369356
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21467.761059291533, tolerance: 32.46600276742945
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22751.109658777066, tolerance: 33.13787982969664
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19964.04370990224, tolerance: 32.122385098456625
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20450.149555688215, tolerance: 33.30080425531916
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25217.254395405344, tolerance: 32.541387014369356
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25296.320366326425, tolerance: 32.46600276742945
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26653.190304567826, tolerance: 33.13787982969664
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24768.931563609996, tolerance: 32.122385098456625
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27334.801872827662, tolerance: 33.30080425531916
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14303.762965809794, tolerance: 40.8928827586207
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\andre\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14303.762965809794, tolerance: 40.8928827586207
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.0001, normalize=True, random_state=0)

# %% [markdown]
# ### evaluate model

# %%
# prediction on test data
y_pred_lasso = Lassoregression.predict(poly_lasso.fit_transform(np.array(X_test).reshape(y_test.shape[0],-1)))

# evaluate
r2_lasso = r2_score(y_test, y_pred_lasso)
MAE_lasso=  mean_absolute_error(y_test, y_pred_lasso)
MSE_lasso = mean_squared_error(y_test, y_pred_lasso, squared = True)
RMSE_lasso = mean_squared_error(y_test, y_pred_lasso, squared = False)

print (f'Lasso Regression, {TIME_FRAME}ly')
print('Params: ', Lasso_GS.best_params_)
print ("Training splits: Training set ", SPLIT_TRAIN, ", Test set: ",1-SPLIT_TRAIN)
print ("Features: ", features)
print ('The R^2  of lasso regression is: ', r2_lasso)
print ('The MAE  of lasso regression is: ', MAE_lasso)
print ('The MSE  of lasso regression is: ', MSE_lasso)
print ('The RMSE of lasso regression is: ', RMSE_lasso)
print("Coefficients ", Lassoregression.coef_, "\nIntercept ", Lassoregression.intercept_ )
plot_results(y_pred_lasso)
# Out:
# Lasso Regression, hourly
# Params:  {'lasso__alpha': 0.0001, 'poly__degree': 4}
# Training splits: Training set  0.7 , Test set:  0.30000000000000004
# Features:  ['hour', 'month', 'avg_temp', 'avg_wind', 'is_weekday', 'innerCityMean', 'is_peaktime', 'is_dark']
# The R^2  of lasso regression is:  0.7333483337491455
# The MAE  of lasso regression is:  5.028186474190628
# The MSE  of lasso regression is:  47.88110905217535
# The RMSE of lasso regression is:  6.919617695521578
# Coefficients  [ 0.00000000e+00  1.41881049e+00  1.52720300e+00  0.00000000e+00
#  -1.79032475e-01 -3.41468723e-01  2.02642389e+01  9.22472564e+00
#   0.00000000e+00  3.93411904e-02  1.36002540e-02  6.44983437e-02
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00 -5.42083352e-01
#  -1.77083772e+00  0.00000000e+00 -0.00000000e+00  0.00000000e+00
#   2.82794207e-01  3.87437359e+00  4.61997639e-01 -0.00000000e+00
#   0.00000000e+00 -3.20494804e-03 -1.24085716e-01  2.75597389e-02
#  -0.00000000e+00  3.38694584e-02 -0.00000000e+00 -8.20324104e-02
#   0.00000000e+00 -7.36338295e-01  4.30956815e-01 -0.00000000e+00
#  -0.00000000e+00  4.50668519e+00  0.00000000e+00 -4.69355164e+01
#   1.02021488e-01 -0.00000000e+00  1.06069756e+00 -0.00000000e+00
#   1.05053959e+01 -7.18637604e-04  0.00000000e+00  7.43653472e-05
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00  1.87024814e-06
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -5.81547863e-02 -1.43382425e-02
#   7.24344304e-04  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  
.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  1.13718142e+00 -1.70312001e-01 -0.00000000e+00
#   0.00000000e+00 -0.00000000e+00  1.00879775e+00 -0.00000000e+00
#   2.89421001e-01  0.00000000e+00 -1.29144993e+00 -3.19322377e-01
#  -0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#  -3.40548166e+00 -0.00000000e+00  1.67905204e-01 -0.00000000e+00
#  -3.29294267e+00  3.28891447e+00 -6.06829657e+00  2.74247579e-01
#  -7.81870742e+00 -0.00000000e+00 -0.00000000e+00 -1.27218808e+01
#   5.97958634e+00  6.44086980e+00 -4.06643957e+01 -0.00000000e+00
#   1.14535002e+00 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00
#  -0.00000000e+00  5.78536767e+01 -0.00000000e+00 -0.00000000e+00
#  -1.40427910e+01 -0.00000000e+00  2.99081994e+00 -1.54120162e+01
#  -1.92976714e-15 -0.00000000e+00  8.90459563e-01 -0.00000000e+00
#  -0.00000000e+00 -0.00000000e+00  1.12911150e+00]
# Intercept  -14.549153530591767
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-9ab4ba6fc66d> in <module>
#      17 print ('The RMSE of lasso regression is: ', RMSE_lasso)
#      18 print("Coefficients ", Lassoregression.coef_, "\nIntercept ", Lassoregression.intercept_ )
# ---> 19 plot_results(y_pred_lasso)
#
# NameError: name 'plot_results' is not defined

# %% [markdown]
# ## Model 7: Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
reg_rf = RandomForestRegressor(max_depth=2, random_state=0)
reg_rf.fit(X_train, y_train)

# prediction on test data
y_pred_reg_rf = reg_rf.predict(X_test)

# evaluate
r2_reg_rf = r2_score(y_test, y_pred_reg_rf)
MAE_reg_rf =  mean_absolute_error(y_test, y_pred_reg_rf)
MSE_reg_rf = mean_squared_error(y_test, y_pred_reg_rf, squared = True)
RMSE_reg_rf = mean_squared_error(y_test, y_pred_reg_rf, squared = False)

print (f'Random Forest Regression, {TIME_FRAME}ly')
print ("Training splits: Training set ", SPLIT_TRAIN, ", Test set: ",1-SPLIT_TRAIN)
print ("Features: ", features)
print ('The R^2  of Random Forest regression is: ', r2_reg_rf)
print ('The MAE  of Random Forest regression is: ', MAE_reg_rf)
print ('The MSE  of Random Forest regression is: ', MSE_reg_rf)
print ('The RMSE of Random Forest regression is: ', RMSE_reg_rf)
# Out:
# Random Forest Regression, hourly
# Training splits: Training set  0.7 , Test set:  0.30000000000000004
# Features:  ['hour', 'month', 'avg_temp', 'avg_wind', 'is_weekday', 'innerCityMean', 'is_peaktime', 'is_dark']
# The R^2  of Random Forest regression is:  0.5129406926178328
# The MAE  of Random Forest regression is:  7.077967463004057
# The MSE  of Random Forest regression is:  87.45844396750628
# The RMSE of Random Forest regression is:  9.351921939767584

# %% [markdown]
# ***
# # Results for hourly demand prediction, Bremen

# %% [markdown]
# ## Three Best Prediction models:
# ### Histogram Gradient Boosting regression
# For training and test splits of 78% and 22% and features ['hour', 'month', 'avg_temp', 'is_windy', 'is_rainy', 'is_weekday', 'is_peaktime', 'is_dark'] it yielded following results:
# - The R^2  of Histogram gradient boosting regression is:  0.7655507952033939
# - The MAE  of Histogram gradient boosting regression is:  4.66016110300944
# - The MSE  of Histogram gradient boosting regression is:  42.19256538230443
# - The RMSE of Histogram gradient boosting regression is:  6.49558044999093
#
# ### Gradient Boosting regression
# For training and test splits of 80% and 20% and features ['hour', 'month', 'avg_temp', 'is_windy', 'is_rainy', 'is_weekday', 'is_peaktime', 'is_dark'] it yielded following results:
# - The R^2  of boosting regression is:  0.7352673020222462
# - The MAE  of boosting regression is:  4.963996291277663
# - The MSE  of boosting regression is:  47.934768056570746
# - The RMSE of boosting regression is:  6.923493919732345
#
# ### Polynomial Regression
# For training and test splits of 80% and 20%, polynomial degree of 4 and features ['hour', 'month', 'avg_temp', 'avg_wind', 'is_weekday', 'is_peaktime', 'is_dark'] it yielded following results:
# - The R^2  of polynomial regression is:  0.7332516318048576
# - The MAE  of polynomial regression is:  5.114255564553397
# - The MSE  of polynomial regression is:  48.299742557594335
# - The RMSE of polynomial regression is:  6.949801620017245

# %% [markdown]
# ## General explanation of results
# The best prediction model, using histogram gradient boosting regression, yielded an r^2 score of roughly 76,55%, which means that the model could explain or predict about 3/4 of the provided data and its variance. The Mean Absolute Error of 4,66 Units indicates that the model could predict hourly bike rental demand with a mean deviation of +- 4,66 rentals. The MSE of 42,19 Units and RMSE of 6,49 Units indicate that there are some higher deviations of predicted rental demand when compared to the MAE of 4,66. Higher deviations are obviously undesirable, but due to the highly variable nature of bike rental demand we assume the model performance to be bound by the provided data, which also contains high deviations.
#
# ## Implications
# As the correlation analyis and prediction results suggest, we found evidence for some fairly obvious, but mostly anecdotal statements:
# - The bike rental demand rises as the temperature increases, which can be observed when summer months are approached
# - The hour of day matters for predicting the demand, since there are peak rental times (morning and afternoon hours), as well as lower rental demand in dark/night hours
# - The weather is highly influencing bike rental demand, with rain and wind reducing the number of rented bikes
# - The number of bike rentals is higher in the inner city
# - The bike rental demand varies between weekdays and weekends
#
# Based on this evidence, nextBike can optimize its service, especially the size of operating fleet, by incorporating said factors into their calculations. That could mean they set up a higher number of stations in the inner city, or try to increase their fleet size dramatically when the summer months are approaching. Another approach could be to react on weather forecast, because a drought could be accompanied by increased rental demand. Also the variance of demand between distinct hours of day and between weekdays and weekends open up opportunities to adjust their fleet dynamically, reducing the operation cost to the minimum.
#
# ## Possible Improvement
# The most important and promising improvement lever for futre projects is a more detailed selection of features. The comparison of boosting regressors with the other regression types suggests that a thorough analysis of weather data resulting in categorical weather features could yield even better results. As the boosting regressors have shown similar or worse results in comparison to the other regression types (polynomial, ridge, lasso) on the same features, including continuous weather data, they are comparably better when using simple categorical weather features indicating bad weather (is_windy, is_rainy). Also, the is_dark and hour features could be improved when integrating the fact that days get longer in the summer up to a certain maximum and then getting shorter again, which certainly has an impact on the rentals, as the feature is_dark suggests.

# %% [markdown]
# ***
# # Results for hourly demand prediction, Düsseldorf

# %% [markdown]
# ## Three Best Prediction models:
# ### Histogram Gradient Boosting regression
# For training and test splits of 65% and 35% and features ['month', 'day', 'hour', 'avg_temp', 'avg_wind', 'avg_rain', 'avg_distance', 'is_weekday', 'is_peaktime', 'is_dark', 'is_rainy', 'is_windy'] it yielded following results:
# - The R^2  of Histogram Gradient boosting regression is:  0.7411808660544513
# - The MAE  of Histogram Gradient boosting regression is:  2.7880786787611775
# - The MSE  of Histogram Gradient boosting regression is:  18.741496788001424
# - The RMSE of Histogram Gradient boosting regression is:  4.329145041229437
#
# ### Gradient Boosting regression
# For training and test splits of 65% and 36% and features ['month', 'day', 'hour', 'avg_temp', 'avg_wind', 'avg_rain', 'avg_distance', 'is_weekday', 'is_peaktime', 'is_dark', 'is_rainy', 'is_windy'] it yielded following results:
# - The R^2  of Gradient boosting regression is:  0.7258787397115822
# - The MAE  of Gradient boosting regression is:  2.9139391757316653
# - The MSE  of Gradient boosting regression is:  19.84954760067746
# - The RMSE of Gradient boosting regression is:  4.455283111170092
#
# ### Lasso Regression
# For training and test splits of 80% and 20%, polynomial degree of 7, lambda = 0.1 and features ['hour', 'month', 'avg_temp', 'avg_wind', 'is_weekday', 'is_peaktime', 'is_dark'] it yielded following results:
# - The R^2  of lasso regression is:  0.7225101697778884
# - The MAE  of lasso regression is:  3.291866563147094
# - The MSE  of lasso regression is:  21.779185685758467
# - The RMSE of lasso regression is:  4.666817511512366

# %% [markdown]
# ## General explanation of results
# The best prediction model, using histogram gradient boosting regression, yielded an r^2 score of roughly 74,11%, which means that the model could explain or predict about 3/4 of the provided data and its variance. The Mean Absolute Error of 2.78 Units indicates that the model could predict hourly bike rental demand with a mean deviation of +- 2.78 rentals. The MSE of 18.74 Units and RMSE of 4.32 Units indicate that there are some higher deviations of predicted rental demand when compared to the MAE of 2.78. Higher deviations are obviously undesirable, but due to the highly variable nature of bike rental demand we assume the model performance to be bound by the provided data, which also contains high deviations.
#
# Also, the lower values for MAE, MSE and RMSE in Düsseldorf are most likely due to the fact that there are fewer data points in the Düsseldorf data set, which means there are less deviating values from the regression line.
#
# ## Implications
# As the correlation analyis and prediction results suggest, we found evidence for some fairly obvious, but mostly anecdotal statements:
# - The bike rental demand rises as the temperature increases, which can be observed when summer months are approached
# - The hour of day matters for predicting the demand, since there are peak rental times (morning and afternoon hours), as well as lower rental demand in dark/night hours
# - The weather is highly influencing bike rental demand, with rain and wind reducing the number of rented bikes
# - The number of bike rentals is higher in the inner city
# - The bike rental demand varies between weekdays and weekends
#
# Based on this evidence, nextBike can optimize its service, especially the size of operating fleet, by incorporating said factors into their calculations. That could mean they set up a higher number of stations in the inner city, or try to increase their fleet size dramatically when the summer months are approaching. Another approach could be to react on weather forecast, because a drought could be accompanied by increased rental demand. Also the variance of demand between distinct hours of day and between weekdays and weekends open up opportunities to adjust their fleet dynamically, reducing the operation cost to the minimum.
#
# ## Possible Improvement
# The most important and promising improvement lever for futre projects is a more detailed selection of features. The comparison of boosting regressors with the other regression types suggests that a thorough analysis of weather data resulting in categorical weather features could yield even better results. As the boosting regressors have shown similar or worse results in comparison to the other regression types (polynomial, ridge, lasso) on the same features, including continuous weather data, they are comparably better when using simple categorical weather features indicating bad weather (is_windy, is_rainy). Also, the is_dark and hour features could be improved when integrating the fact that days get longer in the summer up to a certain maximum and then getting shorter again, which certainly has an impact on the rentals, as the feature is_dark suggests.
