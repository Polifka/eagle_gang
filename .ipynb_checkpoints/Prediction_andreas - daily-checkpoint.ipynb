# %% [markdown]
# # Prediction Task:
# ## _Predict bike rental demand as a function of suitable features available in or derived from the data sets_

# %% [markdown]
# ## Libraries and styles

# %%
# importing all relevant libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from datetime import datetime, timedelta
from haversine import haversine, Unit
from matplotlib.dates import date2num

# %%
# set seaborn styles
sns.set()
sns.set_style("whitegrid")
sns.set_palette("rocket")

# set pandas display styles
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', 2000)
pd.set_option('display.max_rows', 500)
# %config IPCompleter.greedy=True

# %% [markdown]
# ## Reading Function

# %%
def read_data(city_name):
    trip_data = pd.read_csv("Project_Data/Combined_Data/"+city_name+".csv", encoding = "ISO-8859-1")
    trip_data["trip_duration"] = pd.to_timedelta(trip_data["trip_duration"])
    trip_data["datetime_start"] = pd.to_datetime(trip_data["datetime_start"])
    trip_data["datetime_end"] = pd.to_datetime(trip_data["datetime_end"])
    trip_data["time"] = pd.to_datetime(trip_data["time"])
    trip_data["day"] = pd.to_datetime(trip_data["day"])
    return trip_data

# %%
dataBr = read_data("Bremen")
dataDu = read_data("Duesseldorf")

# %%
city1 = "Bremen"
city2 = "Duesseldorf"
start_date = "2019-02-01 00:00:00"
end_date = "2019-06-30 23:59:00"
startDate = datetime.fromisoformat(start_date)
endDate = datetime.fromisoformat(end_date)

# %%
# coordinates of city center as [lat, lng]
br_center = [53.078893247451994, 8.8027747491885]
du_center = [51.226815497281706, 6.773786392066722]

# %%
dataBr["distance_from_center_start"] = dataBr.apply(lambda row: haversine((row["orig_lat"], row["orig_lng"]),(br_center[0], br_center[1]),Unit.KILOMETERS), axis=1) 
dataBr["distance_from_center_end"] = dataBr.apply(lambda row: haversine((row["dest_lat"], row["dest_lng"]),(br_center[0], br_center[1]),Unit.KILOMETERS), axis=1) 
dataDu["distance_from_center_start"] = dataDu.apply(lambda row: haversine((row["orig_lat"], row["orig_lng"]),(du_center[0], du_center[1]),Unit.KILOMETERS), axis=1) 
dataDu["distance_from_center_end"] = dataDu.apply(lambda row: haversine((row["dest_lat"], row["dest_lng"]),(du_center[0], du_center[1]),Unit.KILOMETERS), axis=1)

# %% [markdown]
# ***
# ## Data for Prediction Task

# %% [markdown]
# ### Prepare data
# Since we have data sets with single entries (trips) at one specific point of time, it does not make sense to take a value from the single entries as a target (since there is no "rental demand" associated with a single trip). Rather, we have to group the trips by a time unit, e.g. hour or day, and aggregate the number of trips per time unit, so there is a target associated with our data that can be predicted.

# %%
dataBr.head()
# Out:
#    Unnamed: 0        day                time  b_number    city trip_duration   orig_lat  orig_lng   dest_lat  dest_lng  ... fleetsize_monthly  distance  trip_duration_hours  avg_speed  rounded_time_hourly  temp  wind  rain  distance_from_center_start  distance_from_center_end
# 0           0 2019-04-21 2021-02-03 17:34:00     20507  bremen      00:13:00  53.078923  8.884911  53.078711  8.899906  ...               395  1.001900             0.216667   4.624155  2019-04-21 18:00:00  20.4   2.0   0.0                    5.486415                  6.488083
# 1           1 2019-05-23 2021-02-03 15:33:00     20507  bremen      00:07:00  53.078923  8.884911  53.078004  8.876828  ...               373  0.549476             0.116667   4.709793  2019-05-23 16:00:00  20.7   2.4   0.0                    5.486415                  4.947560
# 2           2 2019-06-14 2021-02-03 22:30:00     20507  bremen      00:08:00  53.078923  8.884911  53.074731  8.876003  ...               342  0.755886             0.133333   5.669146  2019-06-14 22:00:00  19.6   4.4   0.0                    5.486415                  4.913475
# 3           3 2019-06-16 2021-02-03 10:00:00     20507  bremen      02:02:00  53.074731  8.876003  53.078923  8.884911  ...               342  0.755886             2.033333   0.371747  2019-06-16 10:00:00  21.6   3.0   0.0                    4.913475                  5.486415
# 4           4 2019-06-16 2021-02-03 12:55:00     20507  bremen      02:23:00  53.078923  8.884911  53.076236  8.891322  ...               342  0.522213             2.383333   0.219110  2019-06-16 13:00:00  21.8   4.4   0.0                    5.486415                  5.922224
#
# [5 rows x 28 columns]

# %% [markdown]
# #### Drop columns that are obviously neither relevant nor useful

# %%
dBr = dataBr.drop(["Unnamed: 0","b_number","day","time","city","fleetsize_weekly","fleetsize_dayly","fleetsize_monthly"], axis=1)
dDu = dataDu.drop(["Unnamed: 0","b_number","day","time","city","fleetsize_weekly","fleetsize_dayly","fleetsize_monthly"], axis=1)

# %%
# group the trips by either hour or day
def process_data_for_city(data, city, start_date, end_date, group):
    '''
    Processes given data and calculates the revenue per hour for a given city in a given time window. Also groups by 
    a given param (hour or day)

    :param data: the dataFrame of a given city
    :param city: a city in string format, e.g. "Bremen" or "Duesseldorf"
    :param start_date: an iso format time string, e.g. "2019-03-28 12:00:00"
    :param end_date: an iso format time string, e.g. "2019-03-31 12:00:00"
    :param group: a string, either "hour" or "day"
    '''

    # sorting of data
    dat = data.sort_values(by=['datetime_start'], axis=0)
 
    def calc_revenue(x):
        '''
        Counts trip duration intervals for each trip, i.e. how much revenue each trip generated,
        by setting the revenue to the number of 30-minute durations fitting into the trip duration,
        and add 1 to the revenue if division of trip duration by 30-minute interval has a remainder
        
        Examples: 
        If a trip was 30 mins long: trip duration / 30 mins --> revenue = 1 
        If a trip was 1 hour 12 mins long: trip duration / 30 mins = 2, remainder = 12 --> revenue = 2+1 = 3
        
        :param x: a trip/row
        '''
        if (x % pd.Timedelta(minutes=30)) > pd.Timedelta(minutes=0):
            return float(math.floor(x / pd.Timedelta(minutes=30) + 1))
        else:
            return float(math.floor(x / pd.Timedelta(minutes=30)))
                              
    # apply calculation to each row
    dat["revenue_per_trip"] = dat["trip_duration"].apply(lambda x: calc_revenue(x))

    # select rows in the given time window
    dat_time_framed = dat.loc[(dat["datetime_start"] > startDate) & (dat["datetime_start"] <= endDate)]
        
    
    # Group data in the given time window by month, day and hours to get to specific hourly level
    # and aggregate on several columns
    times = pd.DatetimeIndex(dat_time_framed.datetime_start)
    grouping = [times.month, times.day, times.hour] if group == "hour" else  [times.month, times.day]
    dat_time_framed["inner"] = dat_time_framed["distance_from_center_start"] <= 1
    groupedBy = dat_time_framed.groupby(grouping).agg(trips_per_time=("datetime_start","count"), revenue_per_time=("revenue_per_trip","sum"), avg_temp=("temp","mean"), avg_wind=("wind","mean"), avg_rain=("rain","mean"), avg_distance=("distance","mean"), innerCity=("inner","sum"), innerCityMean=("inner","mean"),avg_dist_from_center_start=("distance_from_center_start","mean"), avg_dist_from_center_end=("distance_from_center_end","mean"))

    # reset index to get the groupedBy values back as columns
    groupedBy.index.rename(["month", "day", "hour"] if group == "hour" else ["month","day"], inplace=True)
    groupedBy.reset_index(inplace=True)
    
    # generate string date column
    groupedBy["date"] = "2019-" + groupedBy["month"].astype(str) + "-" +  groupedBy["day"].astype(str) + " 00:00:00"

    # generate datetime column for checking of weekdays and remove string date column
    groupedBy["datetime"] = [pd.to_datetime(d) for d in groupedBy.date]
    groupedBy.drop(["date"], axis=1, inplace=True)

    # generate weekday column for later use
    groupedBy["weekday"] = [dt.weekday() for dt in groupedBy.datetime]
    groupedBy.drop(["datetime"], axis=1, inplace=True)


    # check, if date is weekday (.weekday() returns 0 for a monday, and 6 for a sunday)
    groupedBy["is_weekday"] = groupedBy["weekday"] <=4
    groupedBy.drop(["weekday"], axis=1, inplace=True)

    
    return groupedBy

# %%
TIME_FRAME="day"

# %%
br = process_data_for_city(dBr, city1, startDate, endDate, TIME_FRAME)
du = process_data_for_city(dDu, city2, startDate, endDate, TIME_FRAME)

# %%
br.head(15)
# Out:
#     month  day  trips_per_time  revenue_per_time  avg_temp  avg_wind  avg_rain  avg_distance  innerCity  innerCityMean  avg_dist_from_center_start  avg_dist_from_center_end  is_weekday
# 0       2    1             197             226.0  0.060914  4.290863  0.000000      1.524199       81.0       0.411168                    1.875367                  1.968714        True
# 1       2    2             118             152.0  0.450847  3.150000  0.000000      1.489424       32.0       0.271186                    1.774694                  1.954111       False
# 2       2    3             139             169.0  1.653957  3.487050  0.000000      1.590335       41.0       0.294964                    1.724617                  1.780380       False
# 3       2    4             162             182.0  2.485802  5.846296  0.000000      1.742222       50.0       0.308642                    2.154845                  2.272686        True
# 4       2    5             227             272.0  3.875330  4.803965  0.000000      1.587274       88.0       0.387665                    1.899668                  1.835590        True
# 5       2    6             189             226.0  4.842328  4.136508  0.176190      1.633971       77.0       0.407407                    1.906559                  1.925526        True
# 6       2    7             246             281.0  7.625610  7.655285  0.031301      1.468920       81.0       0.329268                    1.975020                  2.027243        True
# 7       2    8             287             361.0  7.823345  7.123345  0.004181      1.467289      118.0       0.411150                    1.940635                  2.033037        True
# 8       2    9             174             204.0  8.030460  9.227011  0.050575      1.391234       40.0       0.229885                    2.299408                  2.291393       False
# 9       2   10             100             108.0  7.146000  7.265000  0.297000      1.675600       34.0       0.340000                    1.872859                  2.052113       False
# 10      2   11             200             254.0  5.712000  9.124500  0.000000      1.443182       54.0       0.270000                    2.085591                  1.983126        True
# 11      2   12             240             271.0  5.356250  4.473750  0.000000      1.612640       77.0       0.320833                    2.100429                  1.965426        True
# 12      2   13             247             281.0  7.127126  5.195547  0.000000      1.519981       93.0       0.376518                    1.883451                  1.963433        True
# 13      2   14             282             330.0  6.863121  2.744326  0.000000      1.788430       96.0       0.340426                    1.953881                  1.955226        True
# 14      2   15             293             350.0  9.054608  2.450853  0.000000      1.913148       91.0       0.310580                    2.023589                  2.057366        True

# %% [markdown]
# ***
# ## Correlation Analysis

# %% [markdown]
# The goal is to select those features (from the set of all features) that are optimally least correlated with each other and highly correlated with the target. As a guideline we could take a boundary correlation value of 0.3 or -0.3 to detect very low correlation and take at least low to medium correlation into consideration. However, some features with low correlation values still might be valuable for the prediction task, and a low correlation value might not filter those out (e.g. wind strength obviously has an impact on driven distance). As a result, all features with correlation below between 0.05 and -0.05 are considered not correlated with each other and are assumed to be able to be independently used in a feature set. The same values apply to selecting those features correlated with the target. However, correlation with the target should be maximized.
#
# https://journals.sagepub.com/doi/pdf/10.1177/875647939000600106
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3576830/

# %% [markdown]
# #### on unprepared data

# %%
# showing the highest correlation values for a given data set with a given correlation metric
# disregards values equal to 1 at the diagonal
def show_high_corr(data, posMin, negMin, corr_method):
    corr = data.corr(method=corr_method)
    corr_val = np.array(corr)
    rows, cols = corr.shape
    flds = list(corr.columns)
    high_corr = []
    
    for i in range(cols):
        for j in range(i, cols):
            if corr_val[i,j] > posMin or corr_val[i,j] < negMin:
                if(i!=j):
                    high_corr.append([flds[i], flds[j], corr_val[i,j]])
    df = pd.DataFrame(high_corr, columns = ['col1', 'col2', 'correlation'])
    return df

# %%
# BREMEN, PEARSON CORRELATION
all_br_pe = show_high_corr(dBr, 0.05, -0.05, "pearson")
all_br_pe
# Out:
#                           col1                        col2  correlation
# 0                     orig_lat                    orig_lng    -0.070743
# 1                     orig_lat                    dest_lat     0.666620
# 2                     orig_lat                    dest_lng    -0.069857
# 3                     orig_lat                    distance     0.098017
# 4                     orig_lat         trip_duration_hours     0.056897
# 5                     orig_lat    distance_from_center_end    -0.064568
# 6                     orig_lng                    dest_lat    -0.066708
# 7                     orig_lng                    dest_lng     0.642663
# 8                     orig_lng                    distance     0.050057
# 9                     orig_lng  distance_from_center_start     0.519234
# 10                    orig_lng    distance_from_center_end     0.333468
# 11                    dest_lat                    dest_lng    -0.072469
# 12                    dest_lat                    distance     0.101439
# 13                    dest_lat  distance_from_center_start    -0.063871
# 14                    dest_lng                        hour     0.074545
# 15                    dest_lng                    distance     0.067554
# 16                    dest_lng  distance_from_center_start     0.333126
# 17                    dest_lng    distance_from_center_end     0.521682
# 18                     weekday                       month     0.054795
# 19                     weekday         trip_duration_hours     0.069665
# 20                     weekday                   avg_speed    -0.054027
# 21                     weekday                        wind    -0.135769
# 22                     weekday                        rain    -0.051645
# 23                       month                        week     0.976644
# 24                       month                    distance     0.050110
# 25                       month                        temp     0.686158
# 26                       month                        wind    -0.082592
# 27                        hour                        temp     0.145488
# 28                        hour                        wind     0.055071
# 29                        week                    distance     0.051888
# 30                        week                        temp     0.722585
# 31                        week                        wind    -0.110579
# 32                    distance         trip_duration_hours     0.228120
# 33                    distance                   avg_speed     0.531795
# 34                    distance  distance_from_center_start     0.165738
# 35                    distance    distance_from_center_end     0.201817
# 36         trip_duration_hours                   avg_speed    -0.392765
# 37         trip_duration_hours                        temp     0.110114
# 38                   avg_speed                        temp    -0.100231
# 39                   avg_speed  distance_from_center_start     0.052689
# 40                   avg_speed    distance_from_center_end     0.068264
# 41                        temp                        rain    -0.053229
# 42  distance_from_center_start    distance_from_center_end     0.668333

# %%
# BREMEN, SPEARMAN CORRELATION
all_br_sp = show_high_corr(dBr, 0.05, -0.05, "spearman")
all_br_sp
# Out:
#                           col1                        col2  correlation
# 0                     orig_lat                    dest_lat     0.455863
# 1                     orig_lat                    distance     0.060518
# 2                     orig_lat         trip_duration_hours     0.050182
# 3                     orig_lng                    dest_lng     0.516679
# 4                     orig_lng  distance_from_center_start     0.557024
# 5                     orig_lng    distance_from_center_end     0.316041
# 6                     dest_lat                        hour    -0.065336
# 7                     dest_lat                    distance     0.056946
# 8                     dest_lng                        hour     0.088366
# 9                     dest_lng  distance_from_center_start     0.317261
# 10                    dest_lng    distance_from_center_end     0.567216
# 11                     weekday                       month     0.061223
# 12                     weekday         trip_duration_hours     0.098117
# 13                     weekday                   avg_speed    -0.055699
# 14                     weekday                        wind    -0.149264
# 15                     weekday                        rain    -0.059010
# 16                       month                        week     0.972424
# 17                       month         trip_duration_hours     0.075689
# 18                       month                        temp     0.711116
# 19                       month                        wind    -0.065019
# 20                       month  distance_from_center_start     0.062404
# 21                       month    distance_from_center_end     0.062854
# 22                        hour                        temp     0.121323
# 23                        hour    distance_from_center_end     0.104935
# 24                        week         trip_duration_hours     0.076549
# 25                        week                        temp     0.744299
# 26                        week                        wind    -0.075756
# 27                        week  distance_from_center_start     0.061660
# 28                        week    distance_from_center_end     0.062455
# 29                    distance         trip_duration_hours     0.591308
# 30                    distance                   avg_speed     0.621012
# 31                    distance                        wind    -0.055574
# 32                    distance  distance_from_center_start     0.161111
# 33                    distance    distance_from_center_end     0.166821
# 34         trip_duration_hours                   avg_speed    -0.118377
# 35         trip_duration_hours                        temp     0.124670
# 36         trip_duration_hours  distance_from_center_start     0.121893
# 37         trip_duration_hours    distance_from_center_end     0.121846
# 38                   avg_speed                        temp    -0.101261
# 39                   avg_speed  distance_from_center_start     0.072734
# 40                   avg_speed    distance_from_center_end     0.080084
# 41                        temp                        rain    -0.101549
# 42                        temp  distance_from_center_start     0.061783
# 43                        temp    distance_from_center_end     0.070556
# 44                        wind                        rain     0.055194
# 45  distance_from_center_start    distance_from_center_end     0.355180

# %% [markdown]
# ##### Bremen
# - geo coordinates have a strong positive correlation with each other
# - geo coordinates have a strong positive correlation with distance from city center
#
# **-->** remove geo coordinates or take only one out of those features with geo coordinates / distance from center
#
# - month, hour and week are highly positively correlated with temp
#
# **-->** try maybe with one out of [month,day,hour] plus temperature (e.g. since both hour and temp could be a valuable feature), or only temperature, or only time values
#
# - distance is highly correlated with trip duration in hours, average speed
#
# **-->** here, take only one feature, since they all rely on each other
#
#
# **lower correlation values that still might be relevant**
# - distance is negatively correlated with wind
# - trip duration is positively correlated with wind
# - avg speed is negatively correlated with temperature
# - temperature is negatively correlated with rain
# - weekday is positively correlated with trip duration and negatively correlated with average speed

# %%
# DÜSSELDORF, PEARSON CORRELATION
all_du_pe = show_high_corr(dDu, 0.05, -0.05, "pearson")
all_du_pe
# Out:
#                           col1                        col2  correlation
# 0                     orig_lat                    orig_lng    -0.111232
# 1                     orig_lat                    dest_lat     0.720237
# 2                     orig_lat                    dest_lng    -0.098727
# 3                     orig_lat                       month    -0.115170
# 4                     orig_lat                        week    -0.127535
# 5                     orig_lat                    distance     0.218181
# 6                     orig_lat         trip_duration_hours     0.064961
# 7                     orig_lat                   avg_speed     0.072530
# 8                     orig_lat                        temp    -0.107898
# 9                     orig_lat  distance_from_center_start     0.114302
# 10                    orig_lng                    dest_lat    -0.111209
# 11                    orig_lng                    dest_lng     0.614139
# 12                    orig_lng                     weekday    -0.060462
# 13                    orig_lng         trip_duration_hours    -0.069887
# 14                    orig_lng  distance_from_center_start     0.483375
# 15                    orig_lng    distance_from_center_end     0.450291
# 16                    dest_lat                    dest_lng    -0.166755
# 17                    dest_lat                       month    -0.120007
# 18                    dest_lat                        week    -0.130805
# 19                    dest_lat                    distance     0.127817
# 20                    dest_lat         trip_duration_hours     0.063750
# 21                    dest_lat                        temp    -0.115439
# 22                    dest_lng                     weekday    -0.067388
# 23                    dest_lng                    distance    -0.086186
# 24                    dest_lng         trip_duration_hours    -0.087322
# 25                    dest_lng  distance_from_center_start     0.449899
# 26                    dest_lng    distance_from_center_end     0.490173
# 27                     weekday         trip_duration_hours     0.060852
# 28                     weekday                   avg_speed    -0.077548
# 29                     weekday                        wind     0.067778
# 30                     weekday  distance_from_center_start    -0.052741
# 31                       month                        hour     0.077439
# 32                       month                        week     0.965694
# 33                       month                    distance    -0.061418
# 34                       month         trip_duration_hours    -0.096838
# 35                       month                        temp     0.617446
# 36                        hour                        week     0.081608
# 37                        hour         trip_duration_hours    -0.056886
# 38                        hour                        temp     0.192913
# 39                        week                    distance    -0.063059
# 40                        week         trip_duration_hours    -0.098813
# 41                        week                        temp     0.672457
# 42                    distance         trip_duration_hours     0.228750
# 43                    distance                   avg_speed     0.440498
# 44                    distance  distance_from_center_start     0.252681
# 45                    distance    distance_from_center_end     0.137894
# 46         trip_duration_hours                   avg_speed    -0.476062
# 47                   avg_speed                        temp    -0.063685
# 48                   avg_speed  distance_from_center_start     0.107487
# 49                   avg_speed    distance_from_center_end     0.083275
# 50                        temp                        wind     0.130979
# 51                        temp                        rain    -0.060179
# 52  distance_from_center_start    distance_from_center_end     0.720708

# %%
# DÜSSELDORF, SPEARMAN CORRELATION
results_du_sp = show_high_corr(dDu, 0.299, -0.299, "spearman")
results_du_sp
# Out:
#                           col1                        col2  correlation
# 0                     orig_lat                    dest_lat     0.625418
# 1                     orig_lng                    dest_lng     0.462044
# 2                     orig_lng  distance_from_center_start     0.377244
# 3                     dest_lng    distance_from_center_end     0.366026
# 4                        month                        week     0.901037
# 5                        month                        temp     0.660971
# 6                         week                        temp     0.710122
# 7                     distance         trip_duration_hours     0.466940
# 8                     distance                   avg_speed     0.541234
# 9          trip_duration_hours                   avg_speed    -0.351040
# 10  distance_from_center_start    distance_from_center_end     0.414580

# %% [markdown]
# ##### Düsseldorf
# - similar to Bremen

# %% [markdown]
# #### on prepared data

# %%
# BREMEN, PEARSON CORRELATION
prep_br_pe = show_high_corr(br, 0.05, -0.05, "pearson")
prep_br_pe
# Out:
#                           col1                        col2  correlation
# 0                        month              trips_per_time     0.786801
# 1                        month            revenue_per_time     0.776149
# 2                        month                    avg_temp     0.779400
# 3                        month                    avg_wind    -0.104318
# 4                        month                avg_distance     0.444272
# 5                        month                   innerCity     0.619647
# 6                        month               innerCityMean    -0.330704
# 7                        month  avg_dist_from_center_start     0.271653
# 8                        month    avg_dist_from_center_end     0.286518
# 9                          day              trips_per_time     0.260044
# 10                         day            revenue_per_time     0.283895
# 11                         day                    avg_temp     0.292021
# 12                         day                    avg_wind    -0.244857
# 13                         day                    avg_rain    -0.226116
# 14                         day                avg_distance     0.198387
# 15                         day                   innerCity     0.203313
# 16                         day               innerCityMean    -0.136530
# 17                         day  avg_dist_from_center_start     0.138767
# 18                         day    avg_dist_from_center_end     0.115695
# 19              trips_per_time            revenue_per_time     0.968975
# 20              trips_per_time                    avg_temp     0.773797
# 21              trips_per_time                    avg_wind    -0.261141
# 22              trips_per_time                    avg_rain    -0.230241
# 23              trips_per_time                avg_distance     0.477721
# 24              trips_per_time                   innerCity     0.894742
# 25              trips_per_time               innerCityMean    -0.188047
# 26              trips_per_time  avg_dist_from_center_start     0.201756
# 27              trips_per_time    avg_dist_from_center_end     0.182967
# 28              trips_per_time                  is_weekday     0.191226
# 29            revenue_per_time                    avg_temp     0.814977
# 30            revenue_per_time                    avg_wind    -0.277990
# 31            revenue_per_time                    avg_rain    -0.249308
# 32            revenue_per_time                avg_distance     0.553147
# 33            revenue_per_time                   innerCity     0.814829
# 34            revenue_per_time               innerCityMean    -0.283191
# 35            revenue_per_time  avg_dist_from_center_start     0.277608
# 36            revenue_per_time    avg_dist_from_center_end     0.257459
# 37            revenue_per_time                  is_weekday     0.075029
# 38                    avg_temp                    avg_wind    -0.174218
# 39                    avg_temp                    avg_rain    -0.126680
# 40                    avg_temp                avg_distance     0.588973
# 41                    avg_temp                   innerCity     0.552272
# 42                    avg_temp               innerCityMean    -0.414054
# 43                    avg_temp  avg_dist_from_center_start     0.464585
# 44                    avg_temp    avg_dist_from_center_end     0.463095
# 45                    avg_wind                    avg_rain     0.176283
# 46                    avg_wind                avg_distance    -0.380545
# 47                    avg_wind                   innerCity    -0.199550
# 48                    avg_wind               innerCityMean     0.172786
# 49                    avg_wind  avg_dist_from_center_start    -0.114645
# 50                    avg_wind    avg_dist_from_center_end    -0.098115
# 51                    avg_wind                  is_weekday     0.117316
# 52                    avg_rain                avg_distance    -0.287876
# 53                    avg_rain                   innerCity    -0.199605
# 54                    avg_rain  avg_dist_from_center_start    -0.148190
# 55                    avg_rain    avg_dist_from_center_end    -0.094780
# 56                avg_distance                   innerCity     0.243010
# 57                avg_distance               innerCityMean    -0.464188
# 58                avg_distance  avg_dist_from_center_start     0.501238
# 59                avg_distance    avg_dist_from_center_end     0.526935
# 60                avg_distance                  is_weekday    -0.255859
# 61                   innerCity               innerCityMean     0.232237
# 62                   innerCity  avg_dist_from_center_start    -0.111057
# 63                   innerCity    avg_dist_from_center_end    -0.091331
# 64                   innerCity                  is_weekday     0.443226
# 65               innerCityMean  avg_dist_from_center_start    -0.714724
# 66               innerCityMean    avg_dist_from_center_end    -0.660498
# 67               innerCityMean                  is_weekday     0.580188
# 68  avg_dist_from_center_start    avg_dist_from_center_end     0.919527
# 69  avg_dist_from_center_start                  is_weekday    -0.282123
# 70    avg_dist_from_center_end                  is_weekday    -0.291000

# %%
# BREMEN, SPEARMAN CORRELATION
prep_br_sp = show_high_corr(br, 0.05, -0.05, "spearman")
prep_br_sp
# Out:
#                           col1                        col2  correlation
# 0                        month              trips_per_time     0.809593
# 1                        month            revenue_per_time     0.809974
# 2                        month                    avg_temp     0.777366
# 3                        month                    avg_rain     0.054557
# 4                        month                avg_distance     0.440068
# 5                        month                   innerCity     0.623606
# 6                        month               innerCityMean    -0.335400
# 7                        month  avg_dist_from_center_start     0.324406
# 8                        month    avg_dist_from_center_end     0.335327
# 9                          day              trips_per_time     0.240675
# 10                         day            revenue_per_time     0.275521
# 11                         day                    avg_temp     0.293767
# 12                         day                    avg_wind    -0.214798
# 13                         day                    avg_rain    -0.234434
# 14                         day                avg_distance     0.201264
# 15                         day                   innerCity     0.176033
# 16                         day               innerCityMean    -0.125721
# 17                         day  avg_dist_from_center_start     0.120944
# 18                         day    avg_dist_from_center_end     0.114891
# 19              trips_per_time            revenue_per_time     0.974578
# 20              trips_per_time                    avg_temp     0.798939
# 21              trips_per_time                    avg_wind    -0.200908
# 22              trips_per_time                    avg_rain    -0.164318
# 23              trips_per_time                avg_distance     0.479616
# 24              trips_per_time                   innerCity     0.897128
# 25              trips_per_time               innerCityMean    -0.178182
# 26              trips_per_time  avg_dist_from_center_start     0.252130
# 27              trips_per_time    avg_dist_from_center_end     0.239908
# 28              trips_per_time                  is_weekday     0.186663
# 29            revenue_per_time                    avg_temp     0.845240
# 30            revenue_per_time                    avg_wind    -0.228176
# 31            revenue_per_time                    avg_rain    -0.197424
# 32            revenue_per_time                avg_distance     0.560193
# 33            revenue_per_time                   innerCity     0.825317
# 34            revenue_per_time               innerCityMean    -0.273710
# 35            revenue_per_time  avg_dist_from_center_start     0.323866
# 36            revenue_per_time    avg_dist_from_center_end     0.320501
# 37            revenue_per_time                  is_weekday     0.083396
# 38                    avg_temp                    avg_wind    -0.182687
# 39                    avg_temp                    avg_rain    -0.111468
# 40                    avg_temp                avg_distance     0.582309
# 41                    avg_temp                   innerCity     0.603167
# 42                    avg_temp               innerCityMean    -0.381603
# 43                    avg_temp  avg_dist_from_center_start     0.454473
# 44                    avg_temp    avg_dist_from_center_end     0.473763
# 45                    avg_wind                    avg_rain     0.324691
# 46                    avg_wind                avg_distance    -0.331752
# 47                    avg_wind                   innerCity    -0.140732
# 48                    avg_wind               innerCityMean     0.133647
# 49                    avg_wind  avg_dist_from_center_start    -0.070182
# 50                    avg_wind                  is_weekday     0.150818
# 51                    avg_rain                avg_distance    -0.384471
# 52                    avg_rain                   innerCity    -0.110192
# 53                    avg_rain               innerCityMean     0.110899
# 54                    avg_rain  avg_dist_from_center_start    -0.128642
# 55                    avg_rain    avg_dist_from_center_end    -0.111552
# 56                    avg_rain                  is_weekday     0.072594
# 57                avg_distance                   innerCity     0.258821
# 58                avg_distance               innerCityMean    -0.442344
# 59                avg_distance  avg_dist_from_center_start     0.483109
# 60                avg_distance    avg_dist_from_center_end     0.527620
# 61                avg_distance                  is_weekday    -0.243438
# 62                   innerCity               innerCityMean     0.225447
# 63                   innerCity                  is_weekday     0.429415
# 64               innerCityMean  avg_dist_from_center_start    -0.701115
# 65               innerCityMean    avg_dist_from_center_end    -0.610179
# 66               innerCityMean                  is_weekday     0.580916
# 67  avg_dist_from_center_start    avg_dist_from_center_end     0.927544
# 68  avg_dist_from_center_start                  is_weekday    -0.232437
# 69    avg_dist_from_center_end                  is_weekday    -0.232792

# %%
# DÜSSELDORF, PEARSON CORRELATION
prep_du_pe = show_high_corr(du, 0.05, -0.05, "pearson")
prep_du_pe
# Out:
#                           col1                        col2  correlation
# 0                        month              trips_per_time     0.796455
# 1                        month            revenue_per_time     0.789888
# 2                        month                    avg_temp     0.710187
# 3                        month                    avg_wind    -0.209496
# 4                        month                avg_distance    -0.270968
# 5                        month                   innerCity     0.738663
# 6                        month  avg_dist_from_center_start    -0.229479
# 7                        month    avg_dist_from_center_end    -0.255924
# 8                          day              trips_per_time     0.267361
# 9                          day            revenue_per_time     0.280449
# 10                         day                    avg_temp     0.352352
# 11                         day                    avg_wind    -0.227412
# 12                         day                    avg_rain    -0.137130
# 13                         day                   innerCity     0.269972
# 14                         day               innerCityMean     0.101104
# 15                         day  avg_dist_from_center_start    -0.220452
# 16                         day    avg_dist_from_center_end    -0.205922
# 17              trips_per_time            revenue_per_time     0.988414
# 18              trips_per_time                    avg_temp     0.829426
# 19              trips_per_time                    avg_wind    -0.229494
# 20              trips_per_time                    avg_rain    -0.116022
# 21              trips_per_time                avg_distance    -0.213642
# 22              trips_per_time                   innerCity     0.916292
# 23              trips_per_time  avg_dist_from_center_start    -0.118306
# 24              trips_per_time    avg_dist_from_center_end    -0.135398
# 25              trips_per_time                  is_weekday    -0.080319
# 26            revenue_per_time                    avg_temp     0.848302
# 27            revenue_per_time                    avg_wind    -0.253931
# 28            revenue_per_time                    avg_rain    -0.124563
# 29            revenue_per_time                avg_distance    -0.172593
# 30            revenue_per_time                   innerCity     0.930105
# 31            revenue_per_time  avg_dist_from_center_start    -0.132090
# 32            revenue_per_time    avg_dist_from_center_end    -0.148621
# 33            revenue_per_time                  is_weekday    -0.123491
# 34                    avg_temp                    avg_wind    -0.209433
# 35                    avg_temp                    avg_rain    -0.127159
# 36                    avg_temp                avg_distance    -0.107392
# 37                    avg_temp                   innerCity     0.789096
# 38                    avg_temp               innerCityMean     0.069497
# 39                    avg_temp  avg_dist_from_center_start    -0.166490
# 40                    avg_temp    avg_dist_from_center_end    -0.187098
# 41                    avg_temp                  is_weekday    -0.097847
# 42                    avg_wind                    avg_rain     0.333253
# 43                    avg_wind                avg_distance     0.183964
# 44                    avg_wind                   innerCity    -0.246760
# 45                    avg_wind  avg_dist_from_center_start     0.231561
# 46                    avg_wind    avg_dist_from_center_end     0.216436
# 47                    avg_wind                  is_weekday    -0.093032
# 48                    avg_rain                avg_distance    -0.062385
# 49                    avg_rain                   innerCity    -0.126180
# 50                    avg_rain               innerCityMean    -0.143001
# 51                    avg_rain  avg_dist_from_center_start     0.056277
# 52                avg_distance                   innerCity    -0.195330
# 53                avg_distance               innerCityMean     0.050914
# 54                avg_distance                  is_weekday    -0.084901
# 55                   innerCity               innerCityMean     0.233469
# 56                   innerCity  avg_dist_from_center_start    -0.169413
# 57                   innerCity    avg_dist_from_center_end    -0.179643
# 58                   innerCity                  is_weekday    -0.213119
# 59               innerCityMean  avg_dist_from_center_start    -0.280957
# 60               innerCityMean    avg_dist_from_center_end    -0.252307
# 61               innerCityMean                  is_weekday    -0.347890
# 62  avg_dist_from_center_start    avg_dist_from_center_end     0.980906

# %%
# DÜSSELDORF, SPEARMAN CORRELATION
prep_du_sp = show_high_corr(du, 0.05, -0.05, "spearman")
prep_du_sp
# Out:
#                           col1                        col2  correlation
# 0                        month              trips_per_time     0.871109
# 1                        month            revenue_per_time     0.850030
# 2                        month                    avg_temp     0.701832
# 3                        month                    avg_wind    -0.152542
# 4                        month                    avg_rain     0.083930
# 5                        month                avg_distance    -0.288226
# 6                        month                   innerCity     0.813951
# 7                        month               innerCityMean     0.052758
# 8                        month  avg_dist_from_center_start     0.050654
# 9                          day              trips_per_time     0.284114
# 10                         day            revenue_per_time     0.284344
# 11                         day                    avg_temp     0.375459
# 12                         day                    avg_wind    -0.172373
# 13                         day                    avg_rain    -0.287981
# 14                         day                avg_distance     0.080142
# 15                         day                   innerCity     0.279085
# 16                         day               innerCityMean     0.095751
# 17                         day  avg_dist_from_center_start    -0.118300
# 18                         day    avg_dist_from_center_end    -0.080590
# 19              trips_per_time            revenue_per_time     0.992051
# 20              trips_per_time                    avg_temp     0.839187
# 21              trips_per_time                    avg_wind    -0.278209
# 22              trips_per_time                    avg_rain    -0.161168
# 23              trips_per_time                avg_distance    -0.165879
# 24              trips_per_time                   innerCity     0.945223
# 25              trips_per_time               innerCityMean     0.150514
# 26            revenue_per_time                    avg_temp     0.845320
# 27            revenue_per_time                    avg_wind    -0.280648
# 28            revenue_per_time                    avg_rain    -0.168696
# 29            revenue_per_time                avg_distance    -0.127254
# 30            revenue_per_time                   innerCity     0.946465
# 31            revenue_per_time               innerCityMean     0.170907
# 32            revenue_per_time    avg_dist_from_center_end    -0.066499
# 33            revenue_per_time                  is_weekday    -0.070800
# 34                    avg_temp                    avg_wind    -0.209544
# 35                    avg_temp                    avg_rain    -0.139012
# 36                    avg_temp                avg_distance    -0.070182
# 37                    avg_temp                   innerCity     0.812346
# 38                    avg_temp               innerCityMean     0.162634
# 39                    avg_temp                  is_weekday    -0.097588
# 40                    avg_wind                    avg_rain     0.296789
# 41                    avg_wind                avg_distance     0.090560
# 42                    avg_wind                   innerCity    -0.258899
# 43                    avg_wind               innerCityMean    -0.123361
# 44                    avg_wind  avg_dist_from_center_start     0.052271
# 45                    avg_wind    avg_dist_from_center_end     0.054953
# 46                    avg_wind                  is_weekday    -0.088362
# 47                    avg_rain                avg_distance    -0.145827
# 48                    avg_rain                   innerCity    -0.181132
# 49                    avg_rain               innerCityMean    -0.201895
# 50                    avg_rain  avg_dist_from_center_start     0.222661
# 51                    avg_rain    avg_dist_from_center_end     0.151953
# 52                    avg_rain                  is_weekday     0.088577
# 53                avg_distance                   innerCity    -0.173256
# 54                avg_distance    avg_dist_from_center_end     0.091296
# 55                avg_distance                  is_weekday    -0.073457
# 56                   innerCity               innerCityMean     0.427466
# 57                   innerCity  avg_dist_from_center_start    -0.125947
# 58                   innerCity    avg_dist_from_center_end    -0.172040
# 59                   innerCity                  is_weekday    -0.162876
# 60               innerCityMean  avg_dist_from_center_start    -0.537377
# 61               innerCityMean    avg_dist_from_center_end    -0.432568
# 62               innerCityMean                  is_weekday    -0.343029
# 63  avg_dist_from_center_start    avg_dist_from_center_end     0.834404
# 64  avg_dist_from_center_start                  is_weekday     0.335348
# 65    avg_dist_from_center_end                  is_weekday     0.240599

# %% [markdown]
# similar to above, but:
# - month is highly correlated with num of trips (**target**), revenue and avg temp
# - hour is highly correlated with num of trips (**target**)
# - day is slightly correlated with num of trips (**target**), revenue and avg temp
# - num of trips (**target**) is highly correlated with revenue and temp

# %% [markdown]
# **condensed for target variable: correlation of features with target variable on prepared data set**

# %%
target_corr_br = pd.DataFrame(data=pd.DataFrame(data=br.corr(method="pearson"))["trips_per_time"]).rename(columns={"trips_per_time": "pearson"})
target_corr_br["spearman"] = pd.DataFrame(data=br.corr(method="spearman"))["trips_per_time"]
target_corr_br
# Out:
#                              pearson  spearman
# month                       0.786801  0.809593
# day                         0.260044  0.240675
# trips_per_time              1.000000  1.000000
# revenue_per_time            0.968975  0.974578
# avg_temp                    0.773797  0.798939
# avg_wind                   -0.261141 -0.200908
# avg_rain                   -0.230241 -0.164318
# avg_distance                0.477721  0.479616
# innerCity                   0.894742  0.897128
# innerCityMean              -0.188047 -0.178182
# avg_dist_from_center_start  0.201756  0.252130
# avg_dist_from_center_end    0.182967  0.239908
# is_weekday                  0.191226  0.186663

# %%
target_corr_du = pd.DataFrame(data=pd.DataFrame(data=du.corr(method="pearson"))["trips_per_time"]).rename(columns={"trips_per_time": "pearson"})
target_corr_du["spearman"] = pd.DataFrame(data=du.corr(method="spearman"))["trips_per_time"]
target_corr_du
# Out:
#                              pearson  spearman
# month                       0.796455  0.871109
# day                         0.267361  0.284114
# trips_per_time              1.000000  1.000000
# revenue_per_time            0.988414  0.992051
# avg_temp                    0.829426  0.839187
# avg_wind                   -0.229494 -0.278209
# avg_rain                   -0.116022 -0.161168
# avg_distance               -0.213642 -0.165879
# innerCity                   0.916292  0.945223
# innerCityMean               0.016261  0.150514
# avg_dist_from_center_start -0.118306  0.044670
# avg_dist_from_center_end   -0.135398 -0.045207
# is_weekday                 -0.080319 -0.041521

# %% [markdown]
# ### Suitable features
# #### those features from pepared data set with corr > 0.05 or < -0.05 and which are assumed to have impact on rental, sorted by assumed impact on rental demand
# - temp
# - month
# - day
# - wind
# - rain
# - avg distance
# - distance from city center
# - weekday

# %% [markdown]
# ***
# ## Select features

# %%
# all possible pre-selected features
# ["month", "day", "avg_temp", "avg_wind", "avg_rain", "avg_distance", "avg_dist_from_center_end", "is_weekday"]

# %% [markdown]
# ##### split into weekday, weekend and combined

# %%
x_br_weekday = br[br["is_weekday"]==True][["month", "day", "avg_temp", "avg_wind", "avg_rain", "avg_distance", "avg_dist_from_center_end"]]
x_br_weekend = br[br["is_weekday"]==False][["month", "day", "avg_temp", "avg_wind", "avg_rain","avg_distance", "avg_dist_from_center_end"]]
x_br_full    = br[["month", "day", "avg_temp", "avg_wind", "avg_rain", "avg_distance", "avg_dist_from_center_end", "is_weekday"]]
y_br_weekday = br[br["is_weekday"]==True]["trips_per_time"]
y_br_weekend = br[br["is_weekday"]==False]["trips_per_time"]
y_br_full = br["trips_per_time"]

# %% [markdown]
# ##### automatically select k best features (features n=8)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import MinMaxScaler

# %%
br_new_wd = SelectKBest(f_regression, k=7).fit_transform(x_br_full,y_br_full)
pd.DataFrame(br_new_wd)
# Out:
#      0   1          2        3            4        5      6
# 0    2   1  0.0609137  4.29086            0   1.5242   True
# 1    2   2   0.450847     3.15            0  1.48942  False
# 2    2   3    1.65396  3.48705            0  1.59033  False
# 3    2   4     2.4858   5.8463            0  1.74222   True
# 4    2   5    3.87533  4.80396            0  1.58727   True
# 5    2   6    4.84233  4.13651      0.17619  1.63397   True
# 6    2   7    7.62561  7.65528    0.0313008  1.46892   True
# 7    2   8    7.82334  7.12334   0.00418118  1.46729   True
# 8    2   9    8.03046  9.22701    0.0505747  1.39123  False
# 9    2  10      7.146    7.265        0.297   1.6756  False
# 10   2  11      5.712   9.1245            0  1.44318   True
# 11   2  12    5.35625  4.47375            0  1.61264   True
# 12   2  13    7.12713  5.19555            0  1.51998   True
# 13   2  14    6.86312  2.74433            0  1.78843   True
# 14   2  15    9.05461  2.45085            0  1.91315   True
# 15   2  16    8.70284  3.15166            0  1.69985  False
# 16   2  17    9.75747  2.42624            0  1.79974  False
# 17   2  18    8.99481  2.46778            0  1.69979   True
# 18   2  19    7.47714   6.7098    0.0130612   1.5941   True
# 19   2  20    8.21398  4.38509            0  1.69497   True
# 20   2  21    8.71092  5.22465    0.0246479  1.59562   True
# 21   2  22    5.78006  3.44341            0    1.677   True
# 22   2  23     5.1112   3.7988            0  1.64024  False
# 23   2  24    9.77848  1.20084            0   1.8664  False
# 24   2  25    9.70228  1.42085            0  1.67664   True
# 25   2  26    8.75495  1.73067            0   1.7871   True
# 26   2  27    11.5753  2.12823            0  1.78454   True
# 27   2  28    5.17797  3.04576            0  1.56171   True
# 28   3   1    6.03015  5.07077   0.00430769  1.49288   True
# 29   3   2    6.81215  3.90607            0  1.50765  False
# 30   3   3    10.3546  7.24537     0.283333  1.76214  False
# 31   3   4    8.65699  11.2241      0.11014  1.41934   True
# 32   3   5    6.80449  7.51826    0.0215569  1.45351   True
# 33   3   6    9.31237  6.11031    0.0618557  1.45964   True
# 34   3   7    9.71712  9.33891    0.0132296  1.57994   True
# 35   3   8    7.21097   6.9798     0.046384  1.82604   True
# 36   3   9    7.82488  10.2806     0.188018  1.66206  False
# 37   3  10     4.4068  4.93495     0.298058  1.46459  False
# 38   3  11    3.65924   6.2564      0.32654  1.58649   True
# 39   3  12    6.61603  7.55122   0.00940767  1.44757   True
# 40   3  13    6.48687   10.849     0.147876  1.28476   True
# 41   3  14    6.70368  8.12699     0.322699  1.47026   True
# 42   3  15      7.425  7.04224    0.0560345  1.53107   True
# 43   3  19     6.6305   3.3285            0  1.50794   True
# 44   3  20    8.77007  4.38092            0  1.38534   True
# 45   3  21    11.1091  4.24248            0  1.56329   True
# 46   3  22    12.9547  2.72065            0  1.73098   True
# 47   3  23    7.91065  3.74525            0  1.71519  False
# 48   3  24    7.41304  3.52411            0   1.7071  False
# 49   3  25    6.35214  6.93643     0.164643  1.49191   True
# 50   3  26    6.76854  5.68629    0.0442368   1.6077   True
# 51   3  27    8.47729  4.61525    0.0142373  1.59986   True
# 52   3  28    10.0231  3.07464            0  1.59662   True
# 53   3  29    12.2445  1.89294            0   1.6484   True
# 54   3  30    13.7969  3.43377            0  1.76971  False
# 55   3  31    8.17324   4.9081            0  1.63034  False
# 56   4   1    7.85314   5.0285            0  1.64641   True
# 57   4   2    10.8504  4.71806    0.0727763  1.57031   True
# 58   4   3    9.34209  2.19311     0.583163  1.52153   True
# 59   4   4    7.43874  2.93901   0.00274725  1.76384   True
# 60   4   5    8.20418  3.66132            0  1.68603   True
# 61   4   6    14.6114  2.65123            0  1.82305  False
# 62   4   7    16.7813  4.44715            0  1.89355  False
# 63   4   8    13.3485  4.32349            0  1.77636   True
# 64   4   9    8.91399   6.4945            0  1.62875   True
# 65   4  10    6.18476  5.09538            0  1.64017   True
# 66   4  11    6.06119   4.5531            0  1.66434   True
# 67   4  12    4.44889  4.91358            0  1.64091   True
# 68   4  13    3.98018  4.44939    0.0713415  1.44172  False
# 69   4  14    6.06079  4.90036   0.00179856  1.84689  False
# 70   4  15    10.5977  4.99447            0  1.56044   True
# 71   4  16    11.2546     5.55            0  1.72517   True
# 72   4  17    14.5345  5.64159            0  1.80142   True
# 73   4  18    16.9656  5.25082            0  1.85722   True
# 74   4  19    18.9345  4.21791            0  1.91694   True
# 75   4  20    16.7945  4.25952            0  1.82754  False
# 76   4  21     17.294  2.96847            0  1.82137  False
# 77   4  22    18.8345   6.9023            0  1.82295   True
# 78   4  23    17.7975  8.41845            0  1.67276   True
# 79   4  24    19.9749  5.50518   0.00784929  1.71014   True
# 80   4  25    17.8065  5.34777    0.0157895  1.78548   True
# 81   4  26    12.3005  4.23014     0.178037  1.56778   True
# 82   4  27    9.91492  2.86825     0.105079  1.47013  False
# 83   4  28    9.78373  1.70271    0.0578313  1.71897  False
# 84   4  29    9.18105  5.02184    0.0571053  1.47079   True
# 85   4  30    12.1919  5.01187            0  1.67437   True
# 86   5   1     10.665  5.23761            0  1.70933   True
# 87   5   2    10.9555  6.88391   0.00857909  1.59343   True
# 88   5   3    7.97981  6.33944    0.0274648  1.54945   True
# 89   5   4     5.9195   4.5595      0.19475  1.67391  False
# 90   5   5     7.3137  4.95068            0  1.87272  False
# 91   5   6     7.7846  5.66086     0.125253   1.4619   True
# 92   5   7    8.98421  2.73387            0  1.60611   True
# 93   5   8    10.7706  4.90129    0.0733906  1.53199   True
# 94   5   9    14.0394  3.50194   0.00970874   1.8105   True
# 95   5  10     10.849   3.9702    0.0518764  1.70935   True
# 96   5  11    10.5234  5.55636            0  1.75197  False
# 97   5  12    10.6141  6.36436            0  1.74203  False
# 98   5  13    10.9401  5.70714            0  1.80934   True
# 99   5  14    12.4613  3.79283            0  1.77336   True
# 100  5  15    13.1519  4.43949            0   1.7146   True
# 101  5  16    10.5054  4.62541          0.1  1.65345   True
# 102  5  17    13.4701  3.93262   0.00179211  1.52814   True
# 103  5  18    18.2671  2.69162            0  1.86217  False
# 104  5  19    17.9758  2.85924            0  1.91918  False
# 105  5  20    19.2835  4.43632            0  1.60261   True
# 106  5  21    13.5582  6.26057     0.242526  1.51163   True
# 107  5  22    13.5982  5.39385            0  1.68719   True
# 108  5  23    17.1138  2.70105            0  1.84262   True
# 109  5  24    17.7994  5.67599            0  1.71534   True
# 110  5  25    12.5104  3.67261            0  1.66966  False
# 111  5  26    17.1133  6.28107    0.0200565  1.54552  False
# 112  5  27    16.1465  5.77059   0.00436433  1.43624   True
# 113  5  28    13.5656  4.80494            0  1.54143   True
# 114  5  29    13.3401  2.30871            0  1.69247   True
# 115  5  30    16.3149  5.53129   0.00643275  1.82726   True
# 116  5  31    20.2785  4.23559  0.000376648  1.70896   True
# 117  6   1    20.5846   4.4733            0  1.85607  False
# 118  6   2    25.1529  4.44567            0  1.83992  False
# 119  6   3    20.1041  4.48105     0.255991  1.59202   True
# 120  6   4    20.9266  3.67132    0.0213178  1.78189   True
# 121  6   5    23.9248  3.05815            0  1.65865   True
# 122  6   6    17.1303   4.7243    0.0230924  1.63867   True
# 123  6   7    19.7599  5.08653    0.0239057  1.73157   True
# 124  6   8    15.6127     7.18    0.0114286  1.70828  False
# 125  6   9    19.1039  3.08402  0.000819672   2.0993  False
# 126  6  10    21.1602  4.66276     0.168878  1.60261   True
# 127  6  11    19.5668  3.07206     0.231377  1.62893   True
# 128  6  12    17.4299  3.51168     0.245223  1.80916   True
# 129  6  13    19.4721  5.28053            0  1.87569   True
# 130  6  14     22.154  4.23061            0  1.78568   True
# 131  6  15    19.0333  5.11578    0.0125604  2.01134  False
# 132  6  16     19.182  3.25714    0.0457143  1.78992  False
# 133  6  17    22.8265  2.96672            0  1.85436   True
# 134  6  18    24.3071  3.20152     0.089882  1.82883   True
# 135  6  19    24.5269  3.01598     0.112938   1.8633   True
# 136  6  20     19.645  4.54218    0.0406003  1.82833   True
# 137  6  21    17.9345  3.74652            0  1.94337   True
# 138  6  22    19.4147  3.99838            0  1.89746  False
# 139  6  23    23.8042  4.37932            0  1.97264  False
# 140  6  24    26.3904  5.21667            0  1.87531   True
# 141  6  25    28.9959  3.99357            0  1.87216   True
# 142  6  26    22.4357  6.01703            0  1.73594   True
# 143  6  27    16.1032  6.02899            0  1.96473   True
# 144  6  28    18.8529  3.31525            0  1.80458   True
# 145  6  29     25.822   2.2325            0  1.81687  False
# 146  6  30    26.0641  6.56782            0   2.0908  False

# %% [markdown]
# #### results from playing around with x_br_weekday, x_br_weekend, x_br_full with k = 1,...,7
# ##### best k features from k=1 to k=7 on weekdays
# - month
# - month, temp
# - month, temp, avg_distance
# - month, temp, avg_distance, avg_dist_from_center_end
# - month, temp, avg_wind, avg_distance, avg_dist_from_center_end
# - month, day, temp, avg_wind, avg_distance, avg_dist_from_center_end
# - month, day, temp, avg_wind, rain, avg_distance, avg_dist_from_center_end
#
# ##### best k features from k=1 to k=7 on weekends
# - month
# - month, temp
# - month, temp, avg_distance
# - month, temp, rain, avg_distance
# - month, day, temp, rain, avg_distance
# - month, day, temp, wind, rain, avg_distance
# - month, day, temp, wind, rain, avg_distance, avg_dist_from_center_end
#
# ##### best k features from k=1 to k=7 on all days
# - month
# - month, temp
# - month, temp, avg_distance
# - month, temp, wind, avg_distance
# - month, day, temp, wind, avg_distance
# - month, day, temp, wind, rain, avg_distance
# - month, day, temp, wind, rain, avg_distance, is_weekday

# %% [markdown]
# ##### for both weekday and weekend  temperature the 3 most important features seem to be month, temp and avg_distance

# %% [markdown]
# ***
# # Prediction

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ##### selected features for Prediction

# %%
# all possible pre-selected features
# ["month", "day", "avg_temp", "avg_wind", "avg_rain", "avg_distance", "avg_dist_from_center_end","innerCityMean","is_weekday"]

# %%
# SELECT FEATURES HERE
city = "Bremen"
# city = "Düsseldorf"

if city == "Bremen":
    features = ["month", "day", "avg_temp", "avg_wind", "avg_rain", "avg_dist_from_center_end", "is_weekday"]
    X_full = br[features]
    y_full = br["trips_per_time"]
else:
    features = ["month", "day", "avg_temp", "avg_wind", "avg_rain", "avg_dist_from_center_end", "is_weekday"]
    X_full = du[features]
    y_full = du["trips_per_time"]

# %%
SPLIT_TRAIN = 0.7
X_train, X_test, y_train, y_test = train_test_split(X_full, y_full, random_state=0, train_size=SPLIT_TRAIN)

# %% [markdown]
# #### visualized target values, train and test

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(20, 10))
sns.lineplot(data=y_train, ax=ax1)
sns.lineplot(data=y_test, ax=ax2)

# %%
from sklearn.experimental import enable_hist_gradient_boosting  # noqa
from sklearn.ensemble import HistGradientBoostingRegressor, GradientBoostingRegressor

# %% [markdown]
# ## Model 1: Histogram Gradient Boosting regression

# %%
## Histogram gradient Boosting
histgrad = HistGradientBoostingRegressor(max_iter=72).fit(X_train, y_train)
histgrad.score(X_train, y_train)

# prediction on test data
y_pred_histgrad = histgrad.predict(X_test)

# evaluate
r2_histgrad = r2_score(y_test, y_pred_histgrad)
MAE_histgrad =  mean_absolute_error(y_test, y_pred_histgrad)
MSE_histgrad = mean_squared_error(y_test, y_pred_histgrad, squared = True)
RMSE_histgrad = mean_squared_error(y_test, y_pred_histgrad, squared = False)

print (f'Histogram Gradient Boosting Regression, {TIME_FRAME}ly')
print ("Training splits: Training set ", SPLIT_TRAIN, ", Test set: ",1-SPLIT_TRAIN)
print ("Features: ", features)
print ('The R^2  of histogram gradient boosting regression is: ', r2_histgrad)
print ('The MAE  of histogram gradient boosting regression is: ', MAE_histgrad)
print ('The MSE  of histogram gradient boosting regression is: ', MSE_histgrad)
print ('The RMSE of histogram gradient boosting regression is: ', RMSE_histgrad, "\n\n")
# Out:
# Histogram Gradient Boosting Regression, dayly
# Training splits: Training set  0.7 , Test set:  0.30000000000000004
# Features:  ['month', 'day', 'avg_temp', 'avg_wind', 'avg_rain', 'avg_dist_from_center_end', 'is_weekday']
# The R^2  of histogram gradient boosting regression is:  0.7946195062576222
# The MAE  of histogram gradient boosting regression is:  46.58957577279122
# The MSE  of histogram gradient boosting regression is:  3592.3253279953715
# The RMSE of histogram gradient boosting regression is:  59.93601027758998

# %% [markdown]
# ## Model 2: Gradient Boosting Regression

# %%
## Gradient Boosting
grad = GradientBoostingRegressor(n_estimators=10000, loss='ls').fit(X_train, y_train)

# prediction on test data
y_pred_grad  = grad.predict(X_test)

# evaluate
r2_grad = r2_score(y_test, y_pred_grad)
MAE_grad =  mean_absolute_error(y_test, y_pred_grad)
MSE_grad = mean_squared_error(y_test, y_pred_grad, squared = True)
RMSE_grad = mean_squared_error(y_test, y_pred_grad, squared = False)

print (f'Gradient Boosting Regression, {TIME_FRAME}ly')
print ("Training splits: Training set ", SPLIT_TRAIN, ", Test set: ",1-SPLIT_TRAIN)
print ("Features: ", features)
print ('The R^2  of gradient boosting regression is: ', r2_grad)
print ('The MAE  of gradient boosting regression is: ', MAE_grad)
print ('The MSE  of gradient boosting regression is: ', MSE_grad)
print ('The RMSE of gradient boosting regression is: ', RMSE_grad)
# Out:
# Gradient Boosting Regression, dayly
# Training splits: Training set  0.7 , Test set:  0.30000000000000004
# Features:  ['month', 'day', 'avg_temp', 'avg_wind', 'avg_rain', 'avg_dist_from_center_end', 'is_weekday']
# The R^2  of gradient boosting regression is:  0.8418494762393597
# The MAE  of gradient boosting regression is:  36.94578516200558
# The MSE  of gradient boosting regression is:  2766.2224478519474
# The RMSE of gradient boosting regression is:  52.594889940487064

# %%
def plot_results(predictions):
    fig, axes = plt.subplots(nrows=len(features), ncols=1, figsize=(15, 40))

    for i in range(0,len(features)):
        axes[i].scatter(X_train[features[i]],y_train, marker='x', color='b')
        axes[i].scatter(X_test[features[i]],predictions, marker='x', color='r')
        axes[i].set_xlabel(features[i])
        axes[i].set_ylabel("Demand")
        axes[i].legend(["Training Set", 'Prediction Set'])

# %% [markdown]
# ## Model 3: Linear regression

# %%
# fit model on training data
model_lin = LinearRegression(normalize = True)
model_lin.fit(X_train, y_train)

# prediction on test data
y_pred_lin = model_lin.predict(X_test)

# evaluate
r2_lin = r2_score(y_test, y_pred_lin)
MAE_lin =  mean_absolute_error(y_test, y_pred_lin)
MSE_lin = mean_squared_error(y_test, y_pred_lin, squared = True)
RMSE_lin = mean_squared_error(y_test, y_pred_lin, squared = False)

print (f'Linear Regression, {TIME_FRAME}ly')
print ("Training splits: Training set ", SPLIT_TRAIN, ", Test set: ",1-SPLIT_TRAIN)
print ("Features: ", features)
print ('The R^2  of linear regression is: ', r2_lin)
print ('The MAE  of linear regression is: ', MAE_lin)
print ('The MSE  of linear regression is: ', MSE_lin)
print ('The RMSE of linear regression is: ', RMSE_lin)
print("Coefficients ", model_lin.coef_, "\nIntercept ", model_lin.intercept_ )
plot_results(y_pred_lin)
# Out:
# Linear Regression, dayly
# Training splits: Training set  0.7 , Test set:  0.30000000000000004
# Features:  ['month', 'day', 'avg_temp', 'avg_wind', 'avg_rain', 'avg_dist_from_center_end', 'is_weekday']
# The R^2  of linear regression is:  0.8082731280324834
# The MAE  of linear regression is:  43.31495963372973
# The MSE  of linear regression is:  3353.508824894413
# The RMSE of linear regression is:  57.90948821129758
# Coefficients  [  59.8258273     1.41961918    6.87537021  -12.60051788 -276.99177718
#   -93.03396665   67.58292148]
# Intercept  266.08420984480466

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

# %% [markdown]
# ## Model 4: polynomial regression

# %% [markdown]
# ### select best degree via grid search and cross validation

# %%
# using grid search to find best degree by the metrics r2 and MAE
# https://scikit-learn.org/stable/modules/model_evaluation.html
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
# https://scikit-learn.org/stable/modules/grid_search.html
param_grid = [
    {'poly__degree': [1, 2, 3, 4, 5, 6, 7, 8]}
  ]
  
pipeline_poly = Pipeline(steps=[('poly', PolynomialFeatures()), ('linear', LinearRegression(normalize = True))])
Poly_GS = GridSearchCV(pipeline_poly, param_grid, cv=5,
                           scoring='r2',
                           return_train_score=True)
Poly_GS.fit(np.array(X_train).reshape(y_train.shape[0],-1), y_train)

poly2 = PolynomialFeatures(degree = Poly_GS.best_params_["poly__degree"])
x_poly2 = poly2.fit_transform(np.array(X_train).reshape(y_train.shape[0],-1))
PolyRegression = LinearRegression(normalize = True)
PolyRegression.fit(x_poly2, y_train)
# Out:
# LinearRegression(normalize=True)

# %% [markdown]
# ### evaluate model

# %%
# prediction on test data
y_pred_poly = PolyRegression.predict(poly2.fit_transform(np.array(X_test).reshape(y_test.shape[0],-1)))

# evaluate
r2_poly = r2_score(y_test, y_pred_poly)
MAE_poly =  mean_absolute_error(y_test, y_pred_poly)
MSE_poly = mean_squared_error(y_test, y_pred_poly, squared = True)
RMSE_poly = mean_squared_error(y_test, y_pred_poly, squared = False)

print (f'Polynomial Regression, {TIME_FRAME}ly, degree: {Poly_GS.best_params_["poly__degree"]}')
print ("Training splits: Training set ", SPLIT_TRAIN, ", Test set: ",1-SPLIT_TRAIN)
print ("Features: ", features)
print ('The R^2  of polynomial regression is: ', r2_poly)
print ('The MAE  of polynomial regression is: ', MAE_poly)
print ('The MSE  of polynomial regression is: ', MSE_poly)
print ('The RMSE of polynomial regression is: ', RMSE_poly)
print("Coefficients ", PolyRegression.coef_, "\nIntercept ", PolyRegression.intercept_ )
plot_results(y_pred1)
# Out:
# Polynomial Regression, dayly, degree: 1
# Training splits: Training set  0.7 , Test set:  0.30000000000000004
# Features:  ['month', 'day', 'avg_temp', 'avg_wind', 'avg_rain', 'avg_dist_from_center_end', 'is_weekday']
# The R^2  of polynomial regression is:  0.8082731280324832
# The MAE  of polynomial regression is:  43.314959633729735
# The MSE  of polynomial regression is:  3353.508824894416
# The RMSE of polynomial regression is:  57.90948821129761
# Coefficients  [   0.           59.8258273     1.41961918    6.87537021  -12.60051788
#  -276.99177718  -93.03396665   67.58292148]
# Intercept  266.08420984480523

# %% [markdown]
# ## Model 5: Ridge regression

# %%
from sklearn.linear_model import Ridge

# %% [markdown]
# ### select best params via grid search and cross validation

# %%
ridge = Ridge()
params_Ridge = {'alpha': [1,0.2, 0.15, 0.13, 0.11, 0.1,0.01,0.001,0.0001,0], "solver": ['svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']}
Ridge_GS = GridSearchCV(ridge, param_grid=params_Ridge, n_jobs=-1, cv=5)
Ridge_GS.fit(X_train,y_train)
Ridgeregression = Ridge(random_state=0, **Ridge_GS.best_params_, normalize=True)
Ridgeregression.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.11, normalize=True, random_state=0, solver='sag')

# %% [markdown]
# ### evaluate model

# %%
# prediction on test data
y_pred_ridge = Ridgeregression.predict(np.array(X_test).reshape(y_test.shape[0],-1))

# evaluate
r2_ridge = r2_score(y_test, y_pred_ridge)
MAE_ridge =  mean_absolute_error(y_test, y_pred_ridge)
MSE_ridge = mean_squared_error(y_test, y_pred_ridge, squared = True)
RMSE_ridge = mean_squared_error(y_test, y_pred_ridge, squared = False)

print (f'Ridge Regression, {TIME_FRAME}ly')
print('Params: ', Ridge_GS.best_params_)
print ("Training splits: Training set ", SPLIT_TRAIN, ", Test set: ",1-SPLIT_TRAIN)
print ("Features: ", features)
print ('The R^2  of ridge regression is: ', r2_ridge)
print ('The MAE  of ridge regression is: ', MAE_ridge)
print ('The MSE  of ridge regression is: ', MSE_ridge)
print ('The RMSE of ridge regression is: ', RMSE_ridge)
print("Coefficients ", Ridgeregression.coef_, "\nIntercept ", Ridgeregression.intercept_ )
plot_results(y_pred_ridge)
# Out:
# Ridge Regression, dayly
# Params:  {'alpha': 0.11, 'solver': 'sag'}
# Training splits: Training set  0.7 , Test set:  0.30000000000000004
# Features:  ['month', 'day', 'avg_temp', 'avg_wind', 'avg_rain', 'avg_dist_from_center_end', 'is_weekday']
# The R^2  of ridge regression is:  0.8146190291037787
# The MAE  of ridge regression is:  42.97684872716695
# The MSE  of ridge regression is:  3242.512202323419
# The RMSE of ridge regression is:  56.94306105508747
# Coefficients  [  51.84024049    1.30466748    7.34900545  -11.98383282 -248.2209282
#   -74.27051732   62.07387301]
# Intercept  255.25872309491993

# %% [markdown]
# ## Model 6: Lasso regression

# %%
from sklearn.linear_model import Lasso

# %% [markdown]
# ### select best degree via grid search and cross validation

# %%
lasso = Lasso()
params_lasso = {'alpha': [1,0.2, 0.15, 0.13, 0.11, 0.1,0.01,0.001,0.0001,0]}
Lasso_GS = GridSearchCV(lasso, param_grid=params_lasso, n_jobs=-1, cv=5)
Lasso_GS.fit(X_train,y_train)
Lassoregression = Lasso(random_state=0, **Lasso_GS.best_params_)
Lassoregression.fit(X_train,y_train)
# Out:
# Lasso(alpha=1, random_state=0)

# %% [markdown]
# ### evaluate model

# %%
# prediction on test data
y_pred_lasso = Lassoregression.predict(np.array(X_test).reshape(y_test.shape[0],-1))

# evaluate
r2_lasso = r2_score(y_test, y_pred_lasso)
MAE_lasso=  mean_absolute_error(y_test, y_pred_lasso)
MSE_lasso = mean_squared_error(y_test, y_pred_lasso, squared = True)
RMSE_lasso = mean_squared_error(y_test, y_pred_lasso, squared = False)

print (f'Lasso Regression, {TIME_FRAME}ly')
print('Params: ', Lasso_GS.best_params_)
print ("Training splits: Training set ", SPLIT_TRAIN, ", Test set: ",1-SPLIT_TRAIN)
print ("Features: ", features)
print ('The R^2  of lasso regression is: ', r2_lasso)
print ('The MAE  of lasso regression is: ', MAE_lasso)
print ('The MSE  of lasso regression is: ', MSE_lasso)
print ('The RMSE of lasso regression is: ', RMSE_lasso)
print("Coefficients ", Lassoregression.coef_, "\nIntercept ", Lassoregression.intercept_ )
plot_results(y_pred_lasso)
# Out:
# Lasso Regression, dayly
# Params:  {'alpha': 1}
# Training splits: Training set  0.7 , Test set:  0.30000000000000004
# Features:  ['month', 'day', 'avg_temp', 'avg_wind', 'avg_rain', 'avg_dist_from_center_end', 'is_weekday']
# The R^2  of lasso regression is:  0.815367412986413
# The MAE  of lasso regression is:  43.080802351128035
# The MSE  of lasso regression is:  3229.4221647659897
# The RMSE of lasso regression is:  56.82800510985749
# Coefficients  [  59.55078823    1.69723098    6.30426559  -13.29360202 -158.89821512
#   -51.84380392   65.60881525]
# Intercept  182.98523630301617

# %% [markdown]
# ***
# # Results for daily demand prediction, Bremen

# %% [markdown]
# ## Three Best Prediction models:
# ### Ridge regression
# For training and test splits of 50% and 50%, polynomial degree of 4, lambda = 0.13 and features ['month', 'day', 'avg_temp', 'avg_wind', 'avg_rain', 'avg_dist_from_center_end', 'is_weekday'] it yielded following results:
# - The R^2  of ridge regression is:  **0.8177483364151282**
# - The MAE  of ridge regression is:  **45.817089782652104**
# - The MSE  of ridge regression is:  4003.7751032524047
# - The RMSE of ridge regression is:  **63.275390976685436**
#
# ### Lasso regression
# For training and test splits of 50% and 50%, polynomial degree of 1, lambda = 0.1 and features ['month', 'day', 'avg_temp', 'avg_wind', 'avg_rain', 'avg_dist_from_center_end', 'is_weekday'] it yielded following results:
# - The R^2  of lasso regression is:  0.8132054782032903
# - The MAE  of lasso regression is:  46.668509094328805
# - The MSE  of lasso regression is:  4103.574371189909
# - The RMSE of lasso regression is:  64.05914744351433
#
# ### Polynomial/Linear Regression
# For training and test splits of 50% and 50%, polynomial degree of 1 and features ['month', 'day', 'avg_temp', 'avg_wind', 'avg_rain', 'avg_dist_from_center_end', 'is_weekday'] it yielded following results:
# - The R^2  of polynomial regression is:  0.812678876753451
# - The MAE  of polynomial regression is:  46.541779833181145
# - The MSE  of polynomial regression is:  4115.142955710519
# - The RMSE of polynomial regression is:  64.14938001033619

# %% [markdown]
# ## General explanation of results
# The best prediction model, using ridge regression, yielded an r^2 score of roughly 81,77%, which means that the model could explain or predict above 4/5 of the provided data and its variance correctly. The Mean Absolute Error of 45,81 Units indicates that the model could predict daily bike rental demand with a mean deviation of +- 45,81 rentals. The MSE of 4003,77 Units and RMSE of 63,27 Units indicate that there are some higher deviations of predicted rental demand when compared to the MAE of 45,81. Higher deviations are obviously undesirable, but due to the highly variable nature of bike rental demand we assume the model performance to be bound by the provided data, which also contains high deviations.
#
# ## Implications
# As the correlation analyis and prediction results suggest, we found evidence for some fairly obvious, but mostly anecdotal statements:
# - The bike rental demand rises as the temperature increases, which can be observed when summer months are approached
# - The hour of day matters for predicting the demand, since there are peak rental times (morning and afternoon hours), as well as lower rental demand in dark/night hours
# - The weather is highly influencing bike rental demand, with rain and wind reducing the number of rented bikes
# - The number of bike rentals is higher in the inner city
# - The bike rental demand varies between weekdays and weekends
#
# Based on this evidence, nextBike can optimize its service, especially the size of operating fleet, by incorporating said factors into their calculations. That could mean they set up a higher number of stations in the inner city, or try to increase their fleet size dramatically when the summer months are approaching. Another approach could be to react on weather forecast, because a drought could be accompanied by increased rental demand. Also the variance of demand between distinct hours of day and between weekdays and weekends open up opportunities to adjust their fleet dynamically, reducing the operation cost to the minimum.
#
# ## Possible Improvement
# The most important and promising improvement lever for futre projects is a more detailed selection of features. The comparison of boosting regressors with the other regression types suggests that a thorough analysis of weather data resulting in categorical weather features could yield even better results. As the boosting regressors have shown similar or worse results in comparison to the other regression types (polynomial, ridge, lasso) on the same features, including continuous weather data, they are comparably better when using simple categorical weather features indicating bad weather (is_windy, is_rainy).
#
# Another improvement lever could be the usage of holiday, event and natural event data, e.g. national holidays, soccer games to reduce the daily variance or to better predict high deviations from the mean demand.

# %% [markdown]
# ***
# # Results for daily demand prediction, Düsseldorf

# %% [markdown]
# ## Three Best Prediction models:
# ### Gradient boosting regression
# For training and test splits of 95% and 5%,  and features ['month', 'day', 'avg_temp', 'avg_wind', 'avg_rain', 'avg_dist_from_center_end', 'is_weekday'] it yielded following results:
# - The R^2  of gradient boosting regression is:  **0.9701379868229771**
# - The MAE  of gradient boosting regression is:  **18.386961555600962**
# - The MSE  of gradient boosting regression is:  757.905359936134
# - The RMSE of gradient boosting regression is:  **27.530081001263582**
#
# ### Histogram gradient boosting regression
# For training and test splits of 95% and 5%,  and features ['month', 'day', 'avg_temp', 'avg_wind', 'avg_rain', 'avg_dist_from_center_end', 'is_weekday'] it yielded following results:
# - The R^2  of histogram gradient boosting regression is:  0.9472127738996843
# - The MAE  of histogram gradient boosting regression is:  29.726585936582556
# - The MSE  of histogram gradient boosting regression is:  1339.7529952325372
# - The RMSE of histogram gradient boosting regression is:  36.602636451935226
#
# ### Lasso Regression
# For training and test splits of 95% and 5%, polynomial degree of 4, lambda=0.1 and features ['month', 'day', 'avg_temp', 'avg_wind', 'avg_rain', 'avg_dist_from_center_end', 'is_weekday'] it yielded following results:
# - The R^2  of lasso regression is:  0.9437953775550606
# - The MAE  of lasso regression is:  21.110861895117093
# - The MSE  of lasso regression is:  1426.487368808174
# - The RMSE of lasso regression is:  37.76886771943493

# %% [markdown]
# ## General explanation of results
# The best prediction model, using gradient boosting regression, yielded an r^2 score of roughly 97%, which means that the model could explain or predict most of the provided data and its variance correctly. The Mean Absolute Error of 18,38 Units indicates that the model could predict daily bike rental demand with a mean deviation of +- 18,38 rentals. The MSE of 757,9 Units and RMSE of 27,5 Units indicate that there are some higher deviations of predicted rental demand when compared to the MAE of 18,38. Higher deviations are obviously undesirable, but due to the highly variable nature of bike rental demand we assume the model performance to be bound by the provided data, which also contains high deviations.
# However, the performance of the models for Düsseldorf is significantly higher than for Bremen, which might be due to the fact that there is a more monotonous trend for the data in Düsseldorf.
#
# ## Implications
# As the correlation analyis and prediction results suggest, we found evidence for some fairly obvious, but mostly anecdotal statements:
# - The bike rental demand rises as the temperature increases, which can be observed when summer months are approached
# - The hour of day matters for predicting the demand, since there are peak rental times (morning and afternoon hours), as well as lower rental demand in dark/night hours
# - The weather is highly influencing bike rental demand, with rain and wind reducing the number of rented bikes
# - The number of bike rentals is higher in the inner city
# - The bike rental demand varies between weekdays and weekends
#
# Based on this evidence, nextBike can optimize its service, especially the size of operating fleet, by incorporating said factors into their calculations. That could mean they set up a higher number of stations in the inner city, or try to increase their fleet size dramatically when the summer months are approaching. Another approach could be to react on weather forecast, because a drought could be accompanied by increased rental demand. Also the variance of demand between distinct hours of day and between weekdays and weekends open up opportunities to adjust their fleet dynamically, reducing the operation cost to the minimum.
#
# ## Possible Improvement
# The most important and promising improvement lever for futre projects is a more detailed selection of features. The comparison of boosting regressors with the other regression types suggests that a thorough analysis of weather data resulting in categorical weather features could yield even better results. As the boosting regressors have shown similar or worse results in comparison to the other regression types (polynomial, ridge, lasso) on the same features, including continuous weather data, they are comparably better when using simple categorical weather features indicating bad weather (is_windy, is_rainy).
#
# Another improvement lever could be the usage of holiday, event and natural event data, e.g. national holidays, soccer games to reduce the daily variance or to better predict high deviations from the mean demand.
